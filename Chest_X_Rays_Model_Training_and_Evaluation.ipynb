# %% [markdown]
# <a href="https://colab.research.google.com/github/GabCopetti/Chest-X-Rays-Binary-Classification/blob/main/Chest_X_Rays_Model_Training_and_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# ## 1. Setting up environment
# ***

# %%
#Installing specific Python version
# !sudo apt-get install python3.10
# !python --version
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.10 is already the newest version (3.10.12-1~22.04.5).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Python 3.10.12

# %%
#Installing necessary packages

#Disabling output
# %%capture
# !pip install torch==2.3.1+cu121
# !pip install torchvision==0.18.1+cu121
# !pip install datasets==2.20.0
# !pip install matplotlib==3.7.1
# !pip install requests==2.32.3
# !pip install torchmetrics==1.4.0.post0
# !pip install tqdm==4.66.4
# !pip install sklearn==2.2.0

# %%
#Importing libraries

#Torch
import torch
from torch import nn

#Torchvision
import torchvision
from torchvision.transforms import functional as F

#Import datasets from Hugging Face
import datasets
from datasets import load_dataset

#Matplotlib
import matplotlib.pyplot as plt

#Importing Path to download helper functions from Learn PyTorch repo
import requests
from pathlib import Path

#Importing DataLoader
from torch.utils.data import DataLoader

#Importing tqdm for progress bar
from tqdm.auto import tqdm

#To use in the plotting function
from typing import Dict, List

#For evaluation
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay

# %%
# Download helper functions from Learn PyTorch repo (if not already downloaded)
if Path("helper_functions.py").is_file():
  print("helper_functions.py already exists, skipping download")
else:
  print("Downloading helper_functions.py")
  # Note: you need the "raw" GitHub URL for this to work
  request = requests.get("https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/helper_functions.py")
  with open("helper_functions.py", "wb") as f:
    f.write(request.content)
# Out:
# Downloading helper_functions.py

# %%
#Import accuracy metric
from helper_functions import accuracy_fn

# %%
# Setup device-agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ***
# ## 2. Data preparation
# ***

# %%
#Loading datasets
train_dataset = load_dataset("keremberke/chest-xray-classification", "full", split="train")
valid_dataset = load_dataset("keremberke/chest-xray-classification", "full", split="validation")
test_dataset = load_dataset("keremberke/chest-xray-classification", "full", split="test")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading data:   0%|          | 0.00/144M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/41.3M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/20.7M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4077 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1165 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/582 [00:00<?, ? examples/s]

# %%
train_dataset[0]
# Out:
# {'image_file_path': '/storage/hf-datasets-cache/all/datasets/60340657865253-config-parquet-and-info-keremberke-chest-xray-cla-9d66ea8b/downloads/extracted/8202f7dd6f1edf5e674abe75990eb233fbbca4408e132a3acd5268bd99708e15/NORMAL/IM-0003-0001_jpeg.rf.3fffcf9c33575f8f928b017484f99a64.jpg',
#  'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>,
#  'labels': 0}

# %%
#Changing format to torch.Tensor and losing image_file_path
format = {'type': 'torch', 'device': torch.device(device), 'columns': ['image','labels'], 'format_kwargs':{'dtype': torch.float}}
train_dataset.set_format(**format )
valid_dataset.set_format(**format )
test_dataset.set_format(**format )

# %%
train_dataset[0]
# Out:
# {'image': tensor([[[  0.,  28.,  39.,  ..., 107., 107.,  40.],
#           [  0.,  28.,  39.,  ..., 107., 107.,  40.],
#           [  0.,  28.,  39.,  ..., 106., 107.,  40.],
#           ...,
#           [  1.,  27.,  40.,  ...,  34.,  32.,  14.],
#           [  1.,  27.,  40.,  ...,  34.,  32.,  14.],
#           [  1.,  27.,  40.,  ...,  34.,  32.,  14.]],
#
#          [[  0.,  28.,  39.,  ..., 107., 107.,  40.],
#           [  0.,  28.,  39.,  ..., 107., 107.,  40.],
#           [  0.,  28.,  39.,  ..., 106., 107.,  40.],
#           ...,
#           [  1.,  27.,  40.,  ...,  34.,  32.,  14.],
#           [  1.,  27.,  40.,  ...,  34.,  32.,  14.],
#           [  1.,  27.,  40.,  ...,  34.,  32.,  14.]],
#
#          [[  0.,  28.,  39.,  ..., 107., 107.,  40.],
#           [  0.,  28.,  39.,  ..., 107., 107.,  40.],
#           [  0.,  28.,  39.,  ..., 106., 107.,  40.],
#           ...,
#           [  1.,  27.,  40.,  ...,  34.,  32.,  14.],
#           [  1.,  27.,  40.,  ...,  34.,  32.,  14.],
#           [  1.,  27.,  40.,  ...,  34.,  32.,  14.]]], device='cuda:0'),
#  'labels': tensor(0., device='cuda:0')}

# %%
train_dataset[0]['image'].shape
# Out:
# torch.Size([3, 640, 640])

# %%
def transform(example):
    #Transforming channel number = 3 to channnel number = 1
    example['image'] = F.rgb_to_grayscale(example['image'], num_output_channels=1)
    #Converting pixel values from 0-255 to 0-1
    example['image'] = example['image']/255
    return example

# %%
#Applying transformations to sets
train_dataset = train_dataset.map(transform, batched= True, batch_size=32)
valid_dataset = valid_dataset.map(transform, batched= True, batch_size=32)
test_dataset = test_dataset.map(transform, batched= True, batch_size=32)
# Out:
# Map:   0%|          | 0/4077 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1165 [00:00<?, ? examples/s]
# Map:   0%|          | 0/582 [00:00<?, ? examples/s]

# %%
train_dataset[0]
# Out:
# {'image': tensor([[[0.0000, 0.1098, 0.1529,  ..., 0.4196, 0.4196, 0.1568],
#           [0.0000, 0.1098, 0.1529,  ..., 0.4196, 0.4196, 0.1568],
#           [0.0000, 0.1098, 0.1529,  ..., 0.4156, 0.4196, 0.1568],
#           ...,
#           [0.0039, 0.1059, 0.1568,  ..., 0.1333, 0.1255, 0.0549],
#           [0.0039, 0.1059, 0.1568,  ..., 0.1333, 0.1255, 0.0549],
#           [0.0039, 0.1059, 0.1568,  ..., 0.1333, 0.1255, 0.0549]]],
#         device='cuda:0'),
#  'labels': tensor(0., device='cuda:0')}

# %%
train_dataset[0]['image'].shape
# Out:
# torch.Size([1, 640, 640])

# %%
#Checking if image is unchanged after transformation
plt.imshow(train_dataset[0]['image'].squeeze().cpu(), cmap='gray')

# %%
#Setting up DataLoader

# Setup the batch size hyperparameter
BATCH_SIZE = 32

# Turn datasets into iterables (batches)
train_dataloader = DataLoader((train_dataset), # dataset to turn into iterable
    batch_size=BATCH_SIZE, # how many samples per batch?
    shuffle=True # shuffle data every epoch?
)

valid_dataloader = DataLoader((valid_dataset),
    batch_size=BATCH_SIZE,
    shuffle=False # don't necessarily have to shuffle the validation data
)

test_dataloader = DataLoader((test_dataset),
    batch_size=BATCH_SIZE,
    shuffle=False # don't have to shuffle the test data
)

print(f"Dataloaders: {train_dataloader, valid_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of validation dataloader: {len(valid_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x7f2f2ef4e7d0>, <torch.utils.data.dataloader.DataLoader object at 0x7f2f2ef4e260>)
# Length of train dataloader: 128 batches of 32
# Length of validation dataloader: 37 batches of 32
# Length of test dataloader: 19 batches of 32

# %% [markdown]
# ***
# ## 3. Loss, training and validation functions
# ***

# %%
# Set up loss functions

# Without weight
loss_fn = nn.BCEWithLogitsLoss()

# With weight to take into account class imbalance
# pos_weight = 0/1 ratio = 0.37
loss_fn_weighed = nn.BCEWithLogitsLoss(pos_weight = torch.tensor([0.37]).to(device))

# %%
# Set up train and validation steps

#Train
def train_step(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               accuracy_fn,
               device: torch.device = device):
    #List to store true values and predictions
    y_true_list = []
    y_pred_list = []
    #Loss and accuracy variables
    train_loss, train_acc = 0, 0

    #Put model in train mode
    model.to(device)
    model.train()

    #Loop through batches
    for batch, entry in enumerate(data_loader):
        X = entry['image'].to(device)
        y = entry['labels'].to(device)
        y_true_list.append(y)

        # 1. Forward pass
        y_logits = model(X).squeeze().to(device) # squeeze to remove extra `1` dimensions, this won't work unless model and data are on same device
        y_pred = torch.round(torch.sigmoid(y_logits)).to(device)
        with torch.no_grad():
            y_pred_list.append(y_pred)

        # 2. Calculate loss
        loss = loss_fn(y_logits, y)
        train_loss += loss.item()
        train_acc += accuracy_fn(y_true=y,
                                 y_pred=y_pred)

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Print out how many samples have been seen
        if batch % 32 == 0:
            print(f"Looked at {batch * len(X)}/{len(data_loader.dataset)} samples")

    # Calculate loss, accuracy and f1 score per epoch and print out what's happening
    train_loss /= len(data_loader)
    train_acc /= len(data_loader)
    y_true_list = torch.cat(y_true_list).detach().cpu().numpy()
    y_pred_list = torch.cat(y_pred_list).detach().cpu().numpy()
    train_f1 = f1_score(y_true_list, y_pred_list)

    print(f"Train loss: {train_loss:.5f} | Train accuracy: {train_acc:.2f}% | Train F1: {train_f1:.2f}")
    return train_loss, train_acc, train_f1

#Validation step
def valid_step(data_loader: torch.utils.data.DataLoader,
              model: torch.nn.Module,
              loss_fn: torch.nn.Module,
              accuracy_fn,
              device: torch.device = device):
    y_true_list = []
    y_pred_list = []
    valid_loss, valid_acc = 0, 0
    model.to(device)
    model.eval() # put model in eval mode
    # Turn on inference context manager
    with torch.inference_mode():
        for entry in data_loader:
            # Send data to GPU
            X = entry['image'].to(device)
            y = entry['labels'].to(device)
            y_true_list.append(y)

            # 1. Forward pass
            valid_logits = model(X).squeeze().to(device)
            valid_pred = torch.round(torch.sigmoid(valid_logits)).to(device)
            y_pred_list.append(valid_pred)

            # 2. Calculate loss and accuracy
            valid_loss += loss_fn(valid_logits, y).item()
            valid_acc += accuracy_fn(y_true=y, y_pred=valid_pred)

        # Adjust metrics and print out
        valid_loss /= len(data_loader)
        valid_acc /= len(data_loader)
        y_true_list = torch.cat(y_true_list).cpu()
        y_pred_list = torch.cat(y_pred_list).cpu()
        valid_f1 = f1_score(y_true_list, y_pred_list)
        print(f"Validation loss: {valid_loss:.5f} | Validation accuracy: {valid_acc:.2f}%\n | Validation F1: {valid_f1:.2f}")
        return valid_loss, valid_acc, valid_f1

# %%
torch.manual_seed(42)

# 1. Take in various parameters required for training and validation steps
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          valid_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int = 5):

    # Create empty results dictionary
    results = {"train_loss": [],
            "train_acc": [],
            "train_f1": [],
            "valid_loss": [],
            "valid_acc": [],
            "valid_f1": []
              }

    # Train and validate model
    for epoch in tqdm(range(epochs)):
        print(f"Epoch: {epoch}\n---------")
        train_loss, train_acc, train_f1 = train_step(data_loader=train_dataloader,
                                        model=model,
                                        loss_fn=loss_fn,
                                        optimizer=optimizer,
                                        accuracy_fn=accuracy_fn,
                                        device=device
                                        )
        valid_loss, valid_acc, valid_f1 = valid_step(data_loader=valid_dataloader,
                                    model=model,
                                    loss_fn=loss_fn,
                                    accuracy_fn=accuracy_fn,
                                    device=device
                                    )
        # Update results dictionary
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["train_f1"].append(train_f1)
        results["valid_loss"].append(valid_loss)
        results["valid_acc"].append(valid_acc)
        results["valid_f1"].append(valid_f1)

    # Return the filled results at the end of the epochs
    return results

# %% [markdown]
# ***
# ## 4. Function to plot loss and accuracy graphs
# ***

# %%
def plot_loss_curves(results: Dict[str, List[float]]):
    """Plots training curves of a results dictionary.

    Args:
        results (dict): dictionary containing list of values, e.g.
            {"train_loss": [...],
             "train_acc": [...],
             "valid_loss": [...],
             "valid_acc": [...]}
             "train_f1": [...],
             "valid_f1": [...]}
    """

    # Get the loss values of the results dictionary (training and validation)
    loss = results['train_loss']
    valid_loss = results['valid_loss']

    # Get the accuracy values of the results dictionary (training and validation)
    accuracy = results['train_acc']
    valid_accuracy = results['valid_acc']

    # Get the f1 values of the results dictionary (training and validation)
    f1 = torch.tensor(results['train_f1']).detach().cpu().numpy()
    valid_f1 = torch.tensor(results['valid_f1']).detach().cpu().numpy()

    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup a plot
    plt.figure(figsize=(15, 15))

    # Plot loss
    plt.subplot(2, 2, 1)
    plt.plot(epochs, loss, label='train_loss')
    plt.plot(epochs, valid_loss, label='valid_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

    # Plot accuracy
    plt.subplot(2, 2, 2)
    plt.plot(epochs, accuracy, label='train_accuracy')
    plt.plot(epochs, valid_accuracy, label='valid_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend();

    # Plot F1
    plt.subplot(2, 2, 3)
    plt.plot(epochs, f1, label='train_f1')
    plt.plot(epochs, valid_f1, label='valid_f1')
    plt.title('F1')
    plt.xlabel('Epochs')
    plt.legend();

# %% [markdown]
# ***
# ## 5. Setting up model classes
# ***

# %% [markdown]
# ### Linear models

# %%
#Two linear layers
class XRAYS_linear2(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(), # flattens inputs into single vector
            nn.Linear(in_features=input_shape, out_features=hidden_units),
            nn.Linear(in_features=hidden_units, out_features=output_shape)
        )

    def forward(self, x: torch.Tensor):
        return self.layer_stack(x)

# %%
#Three linear layers
class XRAYS_linear3(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(), # flattens inputs into single vector
            nn.Linear(in_features=input_shape, out_features=hidden_units),
            nn.Linear(in_features=hidden_units, out_features=hidden_units),
            nn.Linear(in_features=hidden_units, out_features=output_shape)
        )

    def forward(self, x: torch.Tensor):
        return self.layer_stack(x)

# %%
#Four linear layers
class XRAYS_linear4(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(), # flattens inputs into single vector
            nn.Linear(in_features=input_shape, out_features=hidden_units),
            nn.Linear(in_features=hidden_units, out_features=hidden_units),
            nn.Linear(in_features=hidden_units, out_features=hidden_units),
            nn.Linear(in_features=hidden_units, out_features=output_shape)
        )

    def forward(self, x: torch.Tensor):
        return self.layer_stack(x)

# %% [markdown]
# ### Non-linear models

# %%
# Two layers
class XRAYS_linear2ReLU(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(), # flattens inputs into single vector
            nn.Linear(in_features=input_shape, out_features=hidden_units),
            nn.ReLU(), #adds non-linearity
            nn.Linear(in_features=hidden_units, out_features=output_shape),
            nn.ReLU() #adds non-linearity
        )

    def forward(self, x: torch.Tensor):
        return self.layer_stack(x)

# %%
# Three layers
class XRAYS_linear3ReLU(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(), # flatten inputs into single vector
            nn.Linear(in_features=input_shape, out_features=hidden_units),
            nn.ReLU(), #adds non-linearity
            nn.Linear(in_features=hidden_units, out_features=hidden_units),
            nn.ReLU(), #adds non-linearity
            nn.Linear(in_features=hidden_units, out_features=output_shape),
            nn.ReLU() #adds non-linearity
        )

    def forward(self, x: torch.Tensor):
        return self.layer_stack(x)

# %%
# Four layers
class XRAYS_linear4ReLU(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(), # flatten inputs into single vector
            nn.Linear(in_features=input_shape, out_features=hidden_units),
            nn.ReLU(), #adds non-linearity
            nn.Linear(in_features=hidden_units, out_features=hidden_units),
            nn.ReLU(), #adds non-linearity
            nn.Linear(in_features=hidden_units, out_features=hidden_units),
            nn.ReLU(), #adds non-linearity
            nn.Linear(in_features=hidden_units, out_features=output_shape),
            nn.ReLU() #adds non-linearity
        )

    def forward(self, x: torch.Tensor):
        return self.layer_stack(x)

# %% [markdown]
# ### Convolutional Neural Networks

# %%
# Create a convolutional neural network

#One linear layer at the end

class XRAYS_CNN(nn.Module):
    """
    Model architecture copying TinyVGG from:
    https://poloclub.github.io/cnn-explainer/
    """
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3, # how big is the square that's going over the image?
                      stride=1, # default
                      padding=1),# options = "valid" (no padding) or "same" (output has same shape as input) or int for specific number
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2) # default stride value is same as kernel_size
        )
        self.block_2 = nn.Sequential(
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            # Where did this in_features shape come from?
            # It's because each layer of our network compresses and changes the shape of our inputs data.
            nn.Linear(in_features=hidden_units*25600,
                      out_features=output_shape)
        )

    def forward(self, x: torch.Tensor):
        x = self.block_1(x)
        # print(x.shape)
        x = self.block_2(x)
        # print(x.shape)
        x = self.classifier(x)
        # print(x.shape)
        return x

# %%
#Two linear layers at the end

class XRAYS_CNN2(nn.Module):
    """
    Model architecture copying TinyVGG from:
    https://poloclub.github.io/cnn-explainer/
    """
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3, # how big is the square that's going over the image?
                      stride=1, # default
                      padding=1),# options = "valid" (no padding) or "same" (output has same shape as input) or int for specific number
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2) # default stride value is same as kernel_size
        )
        self.block_2 = nn.Sequential(
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            # Where did this in_features shape come from?
            # It's because each layer of our network compresses and changes the shape of our inputs data.
            nn.Linear(in_features=hidden_units*25600,
                      out_features=hidden_units),
            nn.Linear(in_features=hidden_units,
                      out_features=output_shape)

        )

    def forward(self, x: torch.Tensor):
        x = self.block_1(x)
        # print(x.shape)
        x = self.block_2(x)
        # print(x.shape)
        x = self.classifier(x)
        # print(x.shape)
        return x

# %% [markdown]
# ***
# ## 6. Experiment
# ***

# %% [markdown]
# ### a. Linear models - Changing number of **layers**

# %% [markdown]
# #### Setting up the models

# %%
torch.manual_seed(42)

#Linear layers: 2

model_0 = XRAYS_linear2(input_shape=409600, # one for every pixel
    hidden_units=10, # how many units in the hidden layer
    output_shape=1
)
model_0.to(device)
# Out:
# XRAYS_linear2(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=10, bias=True)
#     (2): Linear(in_features=10, out_features=1, bias=True)
#   )
# )

# %%
#Model optimizer
optimizer_0 = torch.optim.SGD(params=model_0.parameters(), lr=0.0001)

# %%
torch.manual_seed(42)

#Linear layers: 3

model_1 = XRAYS_linear3(input_shape=409600, # one for every pixel
    hidden_units=10, # how many units in the hidden layer
    output_shape=1
)
model_1.to(device)
# Out:
# XRAYS_linear3(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=10, bias=True)
#     (2): Linear(in_features=10, out_features=10, bias=True)
#     (3): Linear(in_features=10, out_features=1, bias=True)
#   )
# )

# %%
optimizer_1 = torch.optim.SGD(params=model_1.parameters(), lr=0.0001)

# %%
torch.manual_seed(42)

#Linear layers: 4

model_2 = XRAYS_linear4(input_shape=409600, # one for every pixel
    hidden_units=10, # how many units in the hidden layer
    output_shape=1
)
model_2.to(device)
# Out:
# XRAYS_linear4(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=10, bias=True)
#     (2): Linear(in_features=10, out_features=10, bias=True)
#     (3): Linear(in_features=10, out_features=10, bias=True)
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
# )

# %%
optimizer_2 = torch.optim.SGD(params=model_2.parameters(), lr=0.0001)

# %% [markdown]
# ***
# #### Training
# ***

# %%
# Set number of epochs
NUM_EPOCHS = 10

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

#Linear layers: 2

# Train model
model_0_results = train(model=model_0,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_0,
                        loss_fn=loss_fn,  #no weight
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.48387 | Train accuracy: 76.92% | Train F1: 0.86
# Validation loss: 0.37860 | Validation accuracy: 88.34%
#  | Validation F1: 0.93
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.36397 | Train accuracy: 85.70% | Train F1: 0.91
# Validation loss: 0.30729 | Validation accuracy: 87.42%
#  | Validation F1: 0.92
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.31216 | Train accuracy: 88.50% | Train F1: 0.93
# Validation loss: 0.27429 | Validation accuracy: 91.68%
#  | Validation F1: 0.94
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.28217 | Train accuracy: 89.60% | Train F1: 0.93
# Validation loss: 0.24803 | Validation accuracy: 90.37%
#  | Validation F1: 0.94
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.26414 | Train accuracy: 90.40% | Train F1: 0.94
# Validation loss: 0.27666 | Validation accuracy: 91.18%
#  | Validation F1: 0.94
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.25165 | Train accuracy: 90.76% | Train F1: 0.94
# Validation loss: 0.24617 | Validation accuracy: 92.61%
#  | Validation F1: 0.95
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.23697 | Train accuracy: 91.19% | Train F1: 0.94
# Validation loss: 0.21308 | Validation accuracy: 92.78%
#  | Validation F1: 0.95
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.23090 | Train accuracy: 91.48% | Train F1: 0.94
# Validation loss: 0.21562 | Validation accuracy: 93.54%
#  | Validation F1: 0.96
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.22522 | Train accuracy: 91.64% | Train F1: 0.94
# Validation loss: 0.24418 | Validation accuracy: 91.77%
#  | Validation F1: 0.94
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.21816 | Train accuracy: 91.92% | Train F1: 0.95
# Validation loss: 0.19256 | Validation accuracy: 92.95%
#  | Validation F1: 0.95

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Linear layers: 3
# Train model
model_1_results = train(model=model_1,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_1,
                        loss_fn=loss_fn,  #no weight
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.52937 | Train accuracy: 73.03% | Train F1: 0.84
# Validation loss: 0.45204 | Validation accuracy: 76.10%
#  | Validation F1: 0.86
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.43411 | Train accuracy: 79.30% | Train F1: 0.88
# Validation loss: 0.38274 | Validation accuracy: 80.15%
#  | Validation F1: 0.88
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37871 | Train accuracy: 84.49% | Train F1: 0.90
# Validation loss: 0.34059 | Validation accuracy: 89.27%
#  | Validation F1: 0.93
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.34271 | Train accuracy: 87.16% | Train F1: 0.92
# Validation loss: 0.30852 | Validation accuracy: 88.85%
#  | Validation F1: 0.93
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.31900 | Train accuracy: 87.98% | Train F1: 0.92
# Validation loss: 0.30395 | Validation accuracy: 92.02%
#  | Validation F1: 0.95
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.30105 | Train accuracy: 89.15% | Train F1: 0.93
# Validation loss: 0.27699 | Validation accuracy: 92.31%
#  | Validation F1: 0.95
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.28331 | Train accuracy: 89.61% | Train F1: 0.93
# Validation loss: 0.26082 | Validation accuracy: 92.15%
#  | Validation F1: 0.95
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.27320 | Train accuracy: 90.46% | Train F1: 0.94
# Validation loss: 0.25692 | Validation accuracy: 92.78%
#  | Validation F1: 0.95
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.26440 | Train accuracy: 90.47% | Train F1: 0.94
# Validation loss: 0.25449 | Validation accuracy: 93.12%
#  | Validation F1: 0.95
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.25493 | Train accuracy: 90.72% | Train F1: 0.94
# Validation loss: 0.22952 | Validation accuracy: 92.48%
#  | Validation F1: 0.95

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Linear layers:4
# Train model
model_2_results = train(model=model_2,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_2,
                        loss_fn=loss_fn,  #no weight
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.55963 | Train accuracy: 72.29% | Train F1: 0.84
# Validation loss: 0.50823 | Validation accuracy: 74.32%
#  | Validation F1: 0.85
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.49664 | Train accuracy: 73.70% | Train F1: 0.85
# Validation loss: 0.45411 | Validation accuracy: 74.83%
#  | Validation F1: 0.85
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.45035 | Train accuracy: 76.36% | Train F1: 0.86
# Validation loss: 0.41576 | Validation accuracy: 82.09%
#  | Validation F1: 0.89
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.41381 | Train accuracy: 81.13% | Train F1: 0.88
# Validation loss: 0.38167 | Validation accuracy: 84.21%
#  | Validation F1: 0.90
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.38599 | Train accuracy: 83.36% | Train F1: 0.90
# Validation loss: 0.36259 | Validation accuracy: 89.36%
#  | Validation F1: 0.93
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.36349 | Train accuracy: 85.99% | Train F1: 0.91
# Validation loss: 0.33508 | Validation accuracy: 89.02%
#  | Validation F1: 0.93
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.34205 | Train accuracy: 87.32% | Train F1: 0.92
# Validation loss: 0.31820 | Validation accuracy: 90.12%
#  | Validation F1: 0.94
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.32719 | Train accuracy: 87.99% | Train F1: 0.92
# Validation loss: 0.30748 | Validation accuracy: 91.22%
#  | Validation F1: 0.94
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.31429 | Train accuracy: 88.69% | Train F1: 0.93
# Validation loss: 0.29441 | Validation accuracy: 91.89%
#  | Validation F1: 0.95
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.30157 | Train accuracy: 89.09% | Train F1: 0.93
# Validation loss: 0.27609 | Validation accuracy: 90.37%
#  | Validation F1: 0.94

# %% [markdown]
# ***
# #### Results
# ***

# %%
model_0_results
# Out:
# {'train_loss': [0.4838724809233099,
#   0.3639689616393298,
#   0.31215895514469594,
#   0.28216813429025933,
#   0.2641354928491637,
#   0.25164957909146324,
#   0.23696518526412547,
#   0.2309048340539448,
#   0.22522123623639345,
#   0.21815733035327867],
#  'train_acc': [76.91932091346153,
#   85.6952373798077,
#   88.5028545673077,
#   89.6014873798077,
#   90.39588341346153,
#   90.76209435096153,
#   91.1865234375,
#   91.4813701923077,
#   91.64100060096153,
#   91.9189453125],
#  'train_f1': [0.8624872132105801,
#   0.9090625487443457,
#   0.9251199999999999,
#   0.9313868613138686,
#   0.9365726398173814,
#   0.9386885245901639,
#   0.9407516822583291,
#   0.9430921052631579,
#   0.9442979564930786,
#   0.9454065644070592],
#  'valid_loss': [0.378603150312965,
#   0.3072900900969634,
#   0.2742944387970744,
#   0.24802739535634583,
#   0.2766596284267065,
#   0.24617116596247698,
#   0.21308390896868062,
#   0.21562047584636793,
#   0.24418112998073166,
#   0.1925550439470523],
#  'valid_acc': [88.3445945945946,
#   87.41554054054055,
#   91.68399168399169,
#   90.37162162162163,
#   91.17723492723493,
#   92.61304573804574,
#   92.78196465696466,
#   93.54209979209979,
#   91.76845114345114,
#   92.95088357588358],
#  'valid_f1': [0.925,
#   0.9197630586968228,
#   0.9446662863662294,
#   0.9369469026548672,
#   0.9381381381381381,
#   0.9490521327014217,
#   0.951668584579977,
#   0.9561659848042081,
#   0.9421686746987952,
#   0.953514739229025]}

# %%
model_1_results
# Out:
# {'train_loss': [0.5293694229330868,
plot_loss_curves(model_0_results)

# %%
# Linear layers: 3
plot_loss_curves(model_1_results)

# %%
# Linear layers: 4
plot_loss_curves(model_2_results)

# %% [markdown]
# ***
# ### b. Linear models - Changing number of **hidden units**
# ***

# %% [markdown]
# #### Setting up models

# %%
#Number of linear layers: 3
#Number of hidden units: 5

torch.manual_seed(42)

model_3 = XRAYS_linear3(input_shape=409600, # one for every pixel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_3.to(device)
# Out:
# XRAYS_linear2(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
optimizer_3 = torch.optim.SGD(params=model_3.parameters(), lr=0.0001)

# %%
#Number of linear layers: 3
#Number of hidden units: 20

torch.manual_seed(42)

model_4 = XRAYS_linear3(input_shape=409600, # one for every pixel
    hidden_units=20, # how many units in the hidden layer
    output_shape=1
)
model_4.to(device)
# Out:
# XRAYS_linear2(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=20, bias=True)
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
optimizer_4 = torch.optim.SGD(params=model_4.parameters(), lr=0.0001)

# %% [markdown]
# ***
# #### Training
# ***

# %%
# Set number of epochs
NUM_EPOCHS = 10

# %%
#Number of linear layers: 3
#Number of hidden units: 5

# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train model
model_3_results = train(model=model_3,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_3,
                        loss_fn=loss_fn, #no weight
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.52164 | Train accuracy: 73.37% | Train F1: 0.84
# Validation loss: 0.44261 | Validation accuracy: 77.36%
#  | Validation F1: 0.75
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.42572 | Train accuracy: 80.20% | Train F1: 0.88
# Validation loss: 0.37383 | Validation accuracy: 82.09%
#  | Validation F1: 0.75
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37115 | Train accuracy: 85.08% | Train F1: 0.90
# Validation loss: 0.33325 | Validation accuracy: 89.27%
#  | Validation F1: 0.74
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.33607 | Train accuracy: 87.55% | Train F1: 0.92
# Validation loss: 0.30199 | Validation accuracy: 89.27%
#  | Validation F1: 0.75
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.31314 | Train accuracy: 88.54% | Train F1: 0.92
# Validation loss: 0.29945 | Validation accuracy: 91.94%
#  | Validation F1: 0.73
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.29589 | Train accuracy: 89.49% | Train F1: 0.93
# Validation loss: 0.27286 | Validation accuracy: 92.28%
#  | Validation F1: 0.74
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.27854 | Train accuracy: 89.88% | Train F1: 0.93
# Validation loss: 0.25618 | Validation accuracy: 92.28%
#  | Validation F1: 0.74
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.26891 | Train accuracy: 90.63% | Train F1: 0.94
# Validation loss: 0.25301 | Validation accuracy: 92.70%
#  | Validation F1: 0.74
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.26051 | Train accuracy: 90.64% | Train F1: 0.94
# Validation loss: 0.25220 | Validation accuracy: 92.87%
#  | Validation F1: 0.73
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.25124 | Train accuracy: 90.94% | Train F1: 0.94
# Validation loss: 0.22604 | Validation accuracy: 92.44%
#  | Validation F1: 0.74

# %%
#Number of linear layers: 3
#Number of hidden units: 20

# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train model
model_4_results = train(model=model_4,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_4,
                        loss_fn=loss_fn,  #no weight
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.56158 | Train accuracy: 72.90% | Train F1: 0.84
# Validation loss: 0.51812 | Validation accuracy: 74.32%
#  | Validation F1: 0.75
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.51015 | Train accuracy: 73.09% | Train F1: 0.84
# Validation loss: 0.47173 | Validation accuracy: 74.41%
#  | Validation F1: 0.75
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.46986 | Train accuracy: 74.38% | Train F1: 0.85
# Validation loss: 0.43739 | Validation accuracy: 78.63%
#  | Validation F1: 0.75
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.43618 | Train accuracy: 78.25% | Train F1: 0.87
# Validation loss: 0.40592 | Validation accuracy: 81.50%
#  | Validation F1: 0.75
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.40942 | Train accuracy: 81.07% | Train F1: 0.88
# Validation loss: 0.38637 | Validation accuracy: 88.09%
#  | Validation F1: 0.75
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.38725 | Train accuracy: 83.77% | Train F1: 0.90
# Validation loss: 0.35923 | Validation accuracy: 87.25%
#  | Validation F1: 0.75
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.36581 | Train accuracy: 85.73% | Train F1: 0.91
# Validation loss: 0.34204 | Validation accuracy: 88.94%
#  | Validation F1: 0.75
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.35021 | Train accuracy: 86.60% | Train F1: 0.91
# Validation loss: 0.33014 | Validation accuracy: 89.95%
#  | Validation F1: 0.74
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.33655 | Train accuracy: 87.91% | Train F1: 0.92
# Validation loss: 0.31526 | Validation accuracy: 90.37%
#  | Validation F1: 0.74
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.32316 | Train accuracy: 88.33% | Train F1: 0.92
# Validation loss: 0.29824 | Validation accuracy: 89.44%
#  | Validation F1: 0.74

# %% [markdown]
# ***
# #### Results
# ***

# %%
#Number of linear layers: 3
#Number of hidden units: 5

model_3_results
# Out:
# {'train_loss': [0.5216382881626487,
#   0.42572315502911806,
#   0.3711466242093593,
#   0.3360725202364847,
#   0.3131431811489165,
#   0.2958857489284128,
#   0.2785405032336712,
#   0.26890742901014164,
#   0.26051314640790224,
#   0.2512369374744594],
#  'train_acc': [73.36801382211539,
#   80.2020733173077,
#   85.0848858173077,
#   87.5507061298077,
#   88.54041466346153,
#   89.49256310096153,
#   89.88131009615384,
#   90.62875600961539,
#   90.64002403846153,
#   90.9423828125],
#  'train_f1': [tensor(0.8381, device='cuda:0'),
#   tensor(0.8783, device='cuda:0'),
#   tensor(0.9044, device='cuda:0'),
#   tensor(0.9188, device='cuda:0'),
#   tensor(0.9235, device='cuda:0'),
#   tensor(0.9300, device='cuda:0'),
#   tensor(0.9322, device='cuda:0'),
#   tensor(0.9360, device='cuda:0'),
#   tensor(0.9368, device='cuda:0'),
#   tensor(0.9385, device='cuda:0')],
#  'valid_loss': [0.4426140322073086,
#   0.3738300506327603,
#   0.3332521609357885,
#   0.3019921807823954,
#   0.2994484402037956,
#   0.27286390839396296,
#   0.256176163215895,
#   0.25301258104878505,
#   0.2522024113584209,
#   0.22604077812787648],
#  'valid_acc': [77.36486486486487,
#   82.0945945945946,
#   89.27364864864865,
#   89.27364864864865,
#   91.93737006237006,
#   92.2752079002079,
#   92.2752079002079,
#   92.6975051975052,
#   92.86642411642411,
#   92.44412681912682],
#  'valid_f1': [tensor(0.7473, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7434, device='cuda:0'),
#   tensor(0.7460, device='cuda:0'),
#   tensor(0.7320, device='cuda:0'),
#   tensor(0.7383, device='cuda:0'),
#   tensor(0.7405, device='cuda:0'),
#   tensor(0.7351, device='cuda:0'),
#   tensor(0.7311, device='cuda:0'),
#   tensor(0.7445, device='cuda:0')]}

# %%
#Number of linear layers: 3
#Number of hidden units: 20

model_4_results
# Out:
# {'train_loss': [0.5615818446967751,
#   0.5101466227788478,
#   0.4698557322844863,
#   0.4361843520309776,
#   0.4094234281219542,
#   0.3872533085523173,
#   0.3658127501839772,
#   0.35020546370651573,
#   0.33654605539049953,
#   0.3231589134084061],
#  'train_acc': [72.90414663461539,
#   73.08631310096153,
#   74.38025841346153,
#   78.2489483173077,
#   81.06971153846153,
#   83.76840444711539,
#   85.73091947115384,
#   86.60043569711539,
#   87.90564903846153,
#   88.3319561298077],
#  'train_f1': [tensor(0.8408, device='cuda:0'),
#   tensor(0.8417, device='cuda:0'),
#   tensor(0.8478, device='cuda:0'),
#   tensor(0.8682, device='cuda:0'),
#   tensor(0.8824, device='cuda:0'),
#   tensor(0.8974, device='cuda:0'),
#   tensor(0.9088, device='cuda:0'),
#   tensor(0.9125, device='cuda:0'),
#   tensor(0.9207, device='cuda:0'),
#   tensor(0.9233, device='cuda:0')],
#  'valid_loss': [0.518124599714537,
#   0.47173039534607447,
#   0.43738627111589584,
#   0.4059235650945354,
#   0.3863747289051881,
#   0.35923402172488134,
#   0.342037595607139,
#   0.3301398379577173,
#   0.31526311627916387,
#   0.2982439346410133],
#  'valid_acc': [74.32432432432432,
#   74.40878378378379,
#   78.63175675675676,
#   81.50337837837837,
#   88.09121621621621,
#   87.24662162162163,
#   88.9358108108108,
#   89.94932432432432,
#   90.37162162162163,
#   89.44256756756756],
#  'valid_f1': [tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7468, device='cuda:0'),
#   tensor(0.7468, device='cuda:0'),
#   tensor(0.7469, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7460, device='cuda:0'),
#   tensor(0.7414, device='cuda:0'),
#   tensor(0.7422, device='cuda:0'),
#   tensor(0.7447, device='cuda:0')]}

# %% [markdown]
# ***
# #### Graphs
# ***

# %%
#Number of linear layers: 3
#Number of hidden units: 5
plot_loss_curves(model_3_results)

# %%
#Number of linear layers: 3
#Number of hidden units: 20
plot_loss_curves(model_4_results)

# %% [markdown]
# ***
# ### c. Linear+ReLU - Changing number of **layers**
# ***

# %% [markdown]
# #### Setting up models

# %%
#Number of linear layers: 2
#Number of hidden units: 10

torch.manual_seed(42)

model_5 = XRAYS_linear2ReLU(input_shape=409600, # one for every pixel
    hidden_units=10, # how many units in the hidden layer
    output_shape=1
)
model_5.to(device)
# Out:
# XRAYS_nonlinear(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=10, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=10, out_features=1, bias=True)
#     (4): ReLU()
#   )
# )

# %%
optimizer_5 = torch.optim.SGD(params=model_5.parameters(), lr=0.0001)

# %%
#Number of linear layers: 3
#Number of hidden units: 10

torch.manual_seed(42)

model_6 = XRAYS_linear3ReLU(input_shape=409600, # one for every pixel
    hidden_units=10, # how many units in the hidden layer
    output_shape=1
)
model_6.to(device)
# Out:
# XRAYS_nonlinear2(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=10, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=10, out_features=10, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=10, out_features=1, bias=True)
#     (6): ReLU()
#   )
# )

# %%
optimizer_6 = torch.optim.SGD(params=model_6.parameters(), lr=0.0001)

# %%
#Number of linear layers: 4
#Number of hidden units: 10

torch.manual_seed(42)

model_7 = XRAYS_linear4ReLU(input_shape=409600, # one for every pixel
    hidden_units=10, # how many units in the hidden layer
    output_shape=1
)
model_7.to(device)
# Out:
# XRAYS_nonlinear3(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=10, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=10, out_features=10, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=10, out_features=10, bias=True)
#     (6): ReLU()
#     (7): Linear(in_features=10, out_features=1, bias=True)
#     (8): ReLU()
#   )
# )

# %%
optimizer_7 = torch.optim.SGD(params=model_7.parameters(), lr=0.0001)

# %% [markdown]
# ***
# #### Training
# ***

# %%
# Set number of epochs
NUM_EPOCHS = 10

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

#Number of linear layers: 2
#Number of hidden units: 10

# Train model
model_5_results = train(model=model_5,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_5,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.52649 | Train accuracy: 73.39% | Train F1: 0.84
# Validation loss: 0.44584 | Validation accuracy: 77.20%
#  | Validation F1: 0.75
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.43642 | Train accuracy: 77.98% | Train F1: 0.87
# Validation loss: 0.39152 | Validation accuracy: 78.46%
#  | Validation F1: 0.75
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.39955 | Train accuracy: 81.51% | Train F1: 0.89
# Validation loss: 0.36549 | Validation accuracy: 86.06%
#  | Validation F1: 0.75
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.69315 | Train accuracy: 27.10% | Train F1: 0.00
# Validation loss: 0.69315 | Validation accuracy: 25.68%
#  | Validation F1: 0.00

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

#Number of linear layers: 4
#Number of hidden units: 10

# Train model
model_7_results = train(model=model_7,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_7,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.69315 | Train accuracy: 27.10% | Train F1: 0.00
# Validation loss: 0.69315 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.69315 | Train accuracy: 27.06% | Train F1: 0.00
# Validation loss: 0.69315 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.69315 | Train accuracy: 27.13% | Train F1: 0.00
# Validation loss: 0.69315 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.69315 | Train accuracy: 27.06% | Train F1: 0.00
# Validation loss: 0.69315 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.69315 | Train accuracy: 27.06% | Train F1: 0.00
# Validation loss: 0.69315 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.69315 | Train accuracy: 27.10% | Train F1: 0.00
# Validation loss: 0.69315 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.69315 | Train accuracy: 27.06% | Train F1: 0.00
# Validation loss: 0.69315 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.69315 | Train accuracy: 27.10% | Train F1: 0.00
# Validation loss: 0.69315 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.69315 | Train accuracy: 27.10% | Train F1: 0.00
# Validation loss: 0.69315 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.69315 | Train accuracy: 27.10% | Train F1: 0.00
# Validation loss: 0.69315 | Validation accuracy: 25.68%
#  | Validation F1: 0.00

# %% [markdown]
# ***
# #### Results
# ***

# %%
#Number of linear layers: 2
#Number of hidden units: 10

model_5_results
# Out:
# {'train_loss': [0.5264910561963916,
#   0.4364248439669609,
#   0.3995487157953903,
#   0.37741961574647576,
#   0.3638768255477771,
#   0.35329308337531984,
#   0.3421025611460209,
#   0.3381916257785633,
#   0.33292692387476563,
#   0.3285857253940776],
#  'train_acc': [73.39242788461539,
#   77.9803936298077,
#   81.50916466346153,
#   83.4003155048077,
#   84.65857872596153,
#   85.69711538461539,
#   86.95162259615384,
#   87.34412560096153,
#   87.85682091346153,
#   88.36763822115384],
#  'train_f1': [tensor(0.8433, device='cuda:0'),
#   tensor(0.8667, device='cuda:0'),
#   tensor(0.8851, device='cuda:0'),
#   tensor(0.8958, device='cuda:0'),
#   tensor(0.9024, device='cuda:0'),
#   tensor(0.9084, device='cuda:0'),
#   tensor(0.9163, device='cuda:0'),
#   tensor(0.9175, device='cuda:0'),
#   tensor(0.9211, device='cuda:0'),
#   tensor(0.9244, device='cuda:0')],
#  'valid_loss': [0.44584138328964645,
#   0.3915248082296268,
#   0.3654880749212729,
#   0.34622614609228597,
#   0.36611395268826874,
#   0.3478467391954886,
#   0.31656054004624085,
#   0.32507812413009435,
#   0.3393301025435731,
#   0.30234762563093287],
#  'valid_acc': [77.19594594594595,
#   78.46283783783784,
#   86.0641891891892,
#   85.05067567567568,
#   92.22972972972973,
#   92.3141891891892,
#   87.66891891891892,
#   92.3141891891892,
#   93.03534303534303,
#   88.76689189189189],
#  'valid_f1': [tensor(0.7477, device='cuda:0'),
#   tensor(0.7473, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7421, device='cuda:0'),
#   tensor(0.7436, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7470, device='cuda:0'),
#   tensor(0.7388, device='cuda:0'),
#   tensor(0.7478, device='cuda:0')]}

# %%
#Number of linear layers: 3
#Number of hidden units: 10

model_6_results
# Out:
# {'train_loss': [0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609],
#  'train_acc': [27.095853365384617,
#   27.06017127403846,
#   27.13153545673077,
#   27.06017127403846,
#   27.06017127403846,
#   27.095853365384617,
#   27.06017127403846,
#   27.095853365384617,
#   27.095853365384617,
#   27.095853365384617],
#  'train_f1': [tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0')],
#  'valid_loss': [0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536],
#  'valid_acc': [25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677],
#  'valid_f1': [tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0')]}

# %%
#Number of linear layers: 4
#Number of hidden units: 10

model_7_results
# Out:
# {'train_loss': [0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609,
#   0.6931471829302609],
#  'train_acc': [27.095853365384617,
#   27.06017127403846,
#   27.13153545673077,
#   27.06017127403846,
#   27.06017127403846,
#   27.095853365384617,
#   27.06017127403846,
#   27.095853365384617,
#   27.095853365384617,
#   27.095853365384617],
#  'train_f1': [tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0')],
#  'valid_loss': [0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536,
#   0.693147184075536],
#  'valid_acc': [25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677],
#  'valid_f1': [tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0')]}

# %% [markdown]
# ***
# #### Graphs
# ***

# %%
#Number of linear layers: 2
#Number of hidden units: 10

plot_loss_curves(model_5_results)

# %%
#Number of linear layers: 3
#Number of hidden units: 10

plot_loss_curves(model_6_results)

# %%
#Number of linear layers: 4
#Number of hidden units: 10

plot_loss_curves(model_7_results)

# %% [markdown]
# ***
# ### d. Linear+ReLU - Changing number of **hidden units**

# %% [markdown]
# #### Setting up models

# %%
#Number of hidden layers: 1
#Number of nodes per layer: 5

torch.manual_seed(42)

model_8 = XRAYS_nonlinear(input_shape=409600, # one for every pixel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_8.to(device)
# Out:
# XRAYS_nonlinear(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=5, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=5, out_features=1, bias=True)
#     (4): ReLU()
#   )
# )

# %%
optimizer_8 = torch.optim.SGD(params=model_8.parameters(), lr=0.0001)

# %%
#Number of hidden layers: 1
#Number of nodes per layer: 20

torch.manual_seed(42)

model_9 = XRAYS_nonlinear(input_shape=409600, # one for every pixel
    hidden_units=20, # how many units in the hidden layer
    output_shape=1
)
model_9.to(device)
# Out:
# XRAYS_nonlinear(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=20, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=20, out_features=1, bias=True)
#     (4): ReLU()
#   )
# )

# %%
optimizer_9 = torch.optim.SGD(params=model_9.parameters(), lr=0.0001)

# %% [markdown]
# #### Training

# %%
#Set number of epochs
NUM_EPOCHS = 10

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train model
model_8_results = train(model=model_8,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_8,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epo
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37437 | Train accuracy: 83.23% | Train F1: 0.90
# Validation loss: 0.35130 | Validation accuracy: 86.23%
#  | Validation F1: 0.75
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.36767 | Train accuracy: 84.12% | Train F1: 0.90
# Validation loss: 0.34875 | Validation accuracy: 88.18%
#  | Validation F1: 0.75
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.36160 | Train accuracy: 84.85% | Train F1: 0.90
# Validation loss: 0.34502 | Validation accuracy: 89.53%
#  | Validation F1: 0.75
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.35532 | Train accuracy: 85.55% | Train F1: 0.91
# Validation loss: 0.33082 | Validation accuracy: 86.66%
#  | Validation F1: 0.75

# %% [markdown]
# #### Results

# %%
model_8_results
# Out:
# {'train_loss': [0.5709852061700076,
#   0.5352476791013032,
#   0.5056563508696854,
#   0.4799545081332326,
#   0.4604949033819139,
#   0.44530480867251754,
#   0.4313159075099975,
#   0.4216925335349515,
#   0.41320301534142345,
#   0.40492586442269385],
#  'train_acc': [72.90414663461539,
#   72.93982872596153,
#   72.86846454326923,
#   72.93982872596153,
#   72.93982872596153,
#   72.90414663461539,
#   72.93982872596153,
#   72.90414663461539,
#   72.90414663461539,
#   72.90414663461539],
#  'train_f1': [tensor(0.8408, device='cuda:0'),
#   tensor(0.8410, device='cuda:0'),
#   tensor(0.8403, device='cuda:0'),
#   tensor(0.8413, device='cuda:0'),
#   tensor(0.8407, device='cuda:0'),
#   tensor(0.8408, device='cuda:0'),
#   tensor(0.8412, device='cuda:0'),
#   tensor(0.8405, device='cuda:0'),
#   tensor(0.8409, device='cuda:0'),
#   tensor(0.8408, device='cuda:0')],
#  'valid_loss': [0.537304597126471,
#   0.5042440834883097,
#   0.4769156462437398,
#   0.45373670313809367,
#   0.43803590254203695,
#   0.4202192236442824,
#   0.40870928562976216,
#   0.40178928383298823,
#   0.394121737899007,
#   0.38119826365161585],
#  'valid_acc': [74.32432432432432,
#   74.32432432432432,
#   74.32432432432432,
#   74.32432432432432,
#   74.32432432432432,
#   74.32432432432432,
#   74.32432432432432,
#   74.32432432432432,
#   74.32432432432432,
#   74.32432432432432],
#  'valid_f1': [tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0')]}

# %%
model_9_results
# Out:
# {'train_loss': [0.5557779150549322,
#   0.488522649044171,
#   0.44347492535598576,
#   0.41615648358128965,
#   0.3994656653376296,
#   0.38672916253563017,
#   0.37437431141734123,
#   0.3676690289285034,
#   0.36159725685138255,
#   0.3553213714621961],
#  'train_acc': [72.90414663461539,
#   73.30603966346153,
#   75.72303185096153,
#   79.0546123798077,
#   80.87439903846153,
#   82.37680288461539,
#   83.2294170673077,
#   84.12146935096153,
#   84.85389122596153,
#   85.5487530048077],
#  'train_f1': [tensor(0.8408, device='cuda:0'),
#   tensor(0.8428, device='cuda:0'),
#   tensor(0.8546, device='cuda:0'),
#   tensor(0.8725, device='cuda:0'),
#   tensor(0.8818, device='cuda:0'),
#   tensor(0.8897, device='cuda:0'),
#   tensor(0.8951, device='cuda:0'),
#   tensor(0.8994, device='cuda:0'),
#   tensor(0.9038, device='cuda:0'),
#   tensor(0.9078, device='cuda:0')],
#  'valid_loss': [0.5019839824856939,
#   0.44413161358317815,
#   0.40880240338879664,
#   0.3864451336699563,
#   0.38203445318582896,
#   0.3627045227063669,
#   0.3513022846466786,
#   0.3487547764907012,
#   0.34502401988248566,
#   0.33081825842728485],
#  'valid_acc': [74.32432432432432,
#   74.74662162162163,
#   79.22297297297297,
#   81.16554054054055,
#   87.24662162162163,
#   86.31756756756756,
#   86.23310810810811,
#   88.17567567567568,
#   89.52702702702703,
#   86.6554054054054],
#  'valid_f1': [tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7468, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7468, device='cuda:0'),
#   tensor(0.7476, device='cuda:0'),
#   tensor(0.7477, device='cuda:0')]}

# %% [markdown]
# #### Graphs

# %%
plot_loss_curves(model_8_results)

# %%
plot_loss_curves(model_9_results)

# %% [markdown]
# ***
# ### e. CNN - 1 L.L. - Changing number of **hidden units**
# ***

# %% [markdown]
# #### Setting up model

# %%
#Number of nodes per layer: 5

torch.manual_seed(42)

model_10 = XRAYS_CNN(input_shape=1, # 1 colour channel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_10.to(device)
# Out:
# XRAYS_CNN(
#   (block_1): Sequential(
#     (0): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=128000, out_features=1, bias=True)
#   )
# )

# %%
optimizer_10 = torch.optim.SGD(params=model_10.parameters(), lr=0.01)

# %%
#Number of nodes per layer: 10

torch.manual_seed(42)

model_11 = XRAYS_CNN(input_shape=1, # 1 colour channel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_11.to(device)
# Out:
# XRAYS_CNN(
#   (block_1): Sequential(
#     (0): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=128000, out_features=1, bias=True)
#   )
# )

# %%
optimizer_11 = torch.optim.SGD(params=model_11.parameters(), lr=0.01)

# %%
#Number of nodes per layer: 20

torch.manual_seed(42)

model_12 = XRAYS_CNN(input_shape=1, # 1 colour channel
    hidden_units=20, # how many units in the hidden layer
    output_shape=1
)
model_12.to(device)
# Out:
# XRAYS_CNN(
#   (block_1): Sequential(
#     (0): Conv2d(1, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512000, out_features=1, bias=True)
#   )
# )

# %%
optimizer_12 = torch.optim.SGD(params=model_12.parameters(), lr=0.01)

# %% [markdown]
# #### Training

# %%
#Set number of epochs
NUM_EPOCHS = 10

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train model
model_10_results = train(model=model_10,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_10,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.58477 | Train accuracy: 72.17% | Train F1: 0.83
# Validation loss: 0.49315 | Validation accuracy: 74.41%
#  | Validation F1: 0.75
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.35183 | Train accuracy: 85.05% | Train F1: 0.90
# Validation loss: 0.24291 | Validation accuracy: 89.19%
#  | Validation F1: 0.75
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.26186 | Train accuracy: 89.76% | Train F1: 0.93
# Validation loss: 0.19935 | Validation accuracy: 92.95%
#  | Validation F1: 0.73
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.22067 | Train accuracy: 91.21% | Train F1: 0.94
# Validation loss: 0.20870 | Validation accuracy: 91.26%
#  | Validation F1: 0.75
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.21975 | Train accuracy: 91.07% | Train F1: 0.94
# Validation loss: 0.40600 | Validation accuracy: 81.56%
#  | Validation F1: 0.65
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.22070 | Train accuracy: 90.70% | Train F1: 0.94
# Validation loss: 0.38521 | Validation accuracy: 82.78%
#  | Validation F1: 0.66
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.19823 | Train accuracy: 91.87% | Train F1: 0.94
# Validation loss: 0.16145 | Validation accuracy: 94.13%
#  | Validation F1: 0.74
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.19300 | Train accuracy: 92.30% | Train F1: 0.95
# Validation loss: 0.18286 | Validation accuracy: 93.04%
#  | Validation F1: 0.73
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.19358 | Train accuracy: 92.18% | Train F1: 0.95
# Validation loss: 0.23722 | Validation accuracy: 90.16%
#  | Validation F1: 0.71
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.17909 | Train accuracy: 93.33% | Train F1: 0.95
# Validation loss: 0.16795 | Validation accuracy: 93.96%
#  | Validation F1: 0.75

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train model
model_11_results = train(model=model_11,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_11,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.58477 | Train accuracy: 72.17% | Train F1: 0.83
# Validation loss: 0.49315 | Validation accuracy: 74.41%
#  | Validation F1: 0.75
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.35183 | Train accuracy: 85.05% | Train F1: 0.90
# Validation loss: 0.24292 | Validation accuracy: 89.19%
#  | Validation F1: 0.75
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.26186 | Train accuracy: 89.76% | Train F1: 0.93
# Validation loss: 0.19933 | Validation accuracy: 92.95%
#  | Validation F1: 0.73
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.22067 | Train accuracy: 91.21% | Train F1: 0.94
# Validation loss: 0.20886 | Validation accuracy: 91.26%
#  | Validation F1: 0.75
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.21976 | Train accuracy: 91.07% | Train F1: 0.94
# Validation loss: 0.40574 | Validation accuracy: 81.56%
#  | Validation F1: 0.65
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.22069 | Train accuracy: 90.70% | Train F1: 0.94
# Validation loss: 0.38526 | Validation accuracy: 82.70%
#  | Validation F1: 0.66
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.19824 | Train accuracy: 91.87% | Train F1: 0.94
# Validation loss: 0.16144 | Validation accuracy: 94.13%
#  | Validation F1: 0.74
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.19301 | Train accuracy: 92.30% | Train F1: 0.95
# Validation loss: 0.18286 | Validation accuracy: 93.04%
#  | Validation F1: 0.73
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.19358 | Train accuracy: 92.18% | Train F1: 0.95
# Validation loss: 0.23717 | Validation accuracy: 90.16%
#  | Validation F1: 0.71
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.17909 | Train accuracy: 93.33% | Train F1: 0.95
# Validation loss: 0.16795 | Validation accuracy: 94.05%
#  | Validation F1: 0.75

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train model
model_12_results = train(model=model_12,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_12,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.53765 | Train accuracy: 74.70% | Train F1: 0.84
# Validation loss: 0.32319 | Validation accuracy: 90.59%
#  | Validation F1: 0.73
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.34952 | Train accuracy: 85.93% | Train F1: 0.90
# Validation loss: 0.20784 | Validation accuracy: 92.74%
#  | Validation F1: 0.73
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.21841 | Train accuracy: 91.28% | Train F1: 0.94
# Validation loss: 0.14483 | Validation accuracy: 93.88%
#  | Validation F1: 0.74
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.18582 | Train accuracy: 93.07% | Train F1: 0.95
# Validation loss: 0.15317 | Validation accuracy: 94.13%
#  | Validation F1: 0.75
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.17070 | Train accuracy: 93.53% | Train F1: 0.95
# Validation loss: 0.27093 | Validation accuracy: 88.39%
#  | Validation F1: 0.69
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.17437 | Train accuracy: 93.41% | Train F1: 0.95
# Validation loss: 0.21488 | Validation accuracy: 91.85%
#  | Validation F1: 0.71
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.15370 | Train accuracy: 94.36% | Train F1: 0.96
# Validation loss: 0.12042 | Validation accuracy: 95.40%
#  | Validation F1: 0.75
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.14925 | Train accuracy: 94.22% | Train F1: 0.96
# Validation loss: 0.13995 | Validation accuracy: 95.23%
#  | Validation F1: 0.74
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.14259 | Train accuracy: 94.66% | Train F1: 0.96
# Validation loss: 0.32593 | Validation accuracy: 86.24%
#  | Validation F1: 0.68
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.14277 | Train accuracy: 94.63% | Train F1: 0.96
# Validation loss: 0.13702 | Validation accuracy: 95.32%
#  | Validation F1: 0.75

# %% [markdown]
# #### Results

# %%
model_10_results
# Out:
# {'train_loss': [0.5847745947539806,
#   0.3518296874826774,
#   0.26186431891983375,
#   0.22066892398288473,
#   0.21975159185240045,
#   0.22070274548605084,
#   0.19823315096437,
#   0.19300201832083985,
#   0.19358005360118113,
#   0.17908928490942344],
#  'train_acc': [72.17172475961539,
#   85.04732572115384,
#   89.75923978365384,
#   91.2128155048077,
#   91.0663311298077,
#   90.70199819711539,
#   91.8701171875,
#   92.29830228365384,
#   92.17623197115384,
#   93.3349609375],
#  'train_f1': [tensor(0.8276, device='cuda:0'),
#   tensor(0.9017, device='cuda:0'),
#   tensor(0.9284, device='cuda:0'),
#   tensor(0.9392, device='cuda:0'),
#   tensor(0.9375, device='cuda:0'),
#   tensor(0.9360, device='cuda:0'),
#   tensor(0.9432, device='cuda:0'),
#   tensor(0.9456, device='cuda:0'),
#   tensor(0.9460, device='cuda:0'),
#   tensor(0.9537, device='cuda:0')],
#  'valid_loss': [0.4931496430087734,
#   0.2429130030544223,
#   0.19935068558599497,
#   0.2087027196445175,
#   0.4060033781302942,
#   0.38521383702754974,
#   0.16145149215653137,
#   0.18286125331714348,
#   0.2372203888119878,
#   0.16795343558329182],
#  'valid_acc': [74.40878378378379,
#   89.1891891891892,
#   92.95088357588358,
#   91.26169438669439,
#   81.55535343035343,
#   82.78326403326403,
#   94.13331600831602,
#   93.03534303534303,
#   90.16372141372142,
#   93.9643970893971],
#  'valid_f1': [tensor(0.7477, device='cuda:0'),
#   tensor(0.7490, device='cuda:0'),
#   tensor(0.7300, device='cuda:0'),
#   tensor(0.7481, device='cuda:0'),
#   tensor(0.6505, device='cuda:0'),
#   tensor(0.6576, device='cuda:0'),
#   tensor(0.7431, device='cuda:0'),
#   tensor(0.7311, device='cuda:0'),
#   tensor(0.7092, device='cuda:0'),
#   tensor(0.7490, device='cuda:0')]}

# %%
model_11_results
# Out:
# {'train_loss': [0.5847741663455963,
#   0.35182687116321176,
#   0.2618602297734469,
#   0.22066963225370273,
#   0.21976384473964572,
#   0.2206910812528804,
#   0.19823698099935427,
#   0.19300597775145434,
#   0.19358451128937304,
#   0.17908779697609134],
#  'train_acc': [72.17172475961539,
#   85.04732572115384,
#   89.75923978365384,
#   91.2128155048077,
#   91.0663311298077,
#   90.70199819711539,
#   91.8701171875,
#   92.29830228365384,
#   92.17623197115384,
#   93.3349609375],
#  'train_f1': [tensor(0.8276, device='cuda:0'),
#   tensor(0.9017, device='cuda:0'),
#   tensor(0.9284, device='cuda:0'),
#   tensor(0.9391, device='cuda:0'),
#   tensor(0.9375, device='cuda:0'),
#   tensor(0.9360, device='cuda:0'),
#   tensor(0.9432, device='cuda:0'),
#   tensor(0.9456, device='cuda:0'),
#   tensor(0.9460, device='cuda:0'),
#   tensor(0.9537, device='cuda:0')],
#  'valid_loss': [0.4931475898704013,
#   0.24291781990511999,
#   0.19932880302941478,
#   0.20886041566326813,
#   0.4057358753036808,
#   0.38526124074249657,
#   0.16144356755791484,
#   0.18285727662009163,
#   0.2371715915364188,
#   0.16795072306853695],
#  'valid_acc': [74.40878378378379,
#   89.1891891891892,
#   92.95088357588358,
#   91.26169438669439,
#   81.55535343035343,
#   82.69880457380457,
#   94.13331600831602,
#   93.03534303534303,
#   90.16372141372142,
#   94.04885654885655],
#  'valid_f1': [tensor(0.7477, device='cuda:0'),
#   tensor(0.7490, device='cuda:0'),
#   tensor(0.7300, device='cuda:0'),
#   tensor(0.7481, device='cuda:0'),
#   tensor(0.6505, device='cuda:0'),
#   tensor(0.6570, device='cuda:0'),
#   tensor(0.7431, device='cuda:0'),
#   tensor(0.7311, device='cuda:0'),
#   tensor(0.7092, device='cuda:0'),
#   tensor(0.7490, device='cuda:0')]}

# %%
model_12_results
# Out:
# {'train_loss': [0.5376528090564534,
#   0.34951805765740573,
#   0.21840955165680498,
#   0.1858183239819482,
#   0.17070209895609878,
#   0.17437261855229735,
#   0.1537020113391918,
#   0.1492523570996127,
#   0.1425909964600578,
#   0.14276737967156805],
#  'train_acc': [74.69576322115384,
#   85.92623197115384,
#   91.2841796875,
#   93.0682842548077,
#   93.5321514423077,
#   93.4100811298077,
#   94.3603515625,
#   94.2157451923077,
#   94.6551983173077,
#   94.62890625],
#  'train_f1': [tensor(0.8439, device='cuda:0'),
#   tensor(0.8998, device='cuda:0'),
#   tensor(0.9393, device='cuda:0'),
#   tensor(0.9518, device='cuda:0'),
#   tensor(0.9543, device='cuda:0'),
#   tensor(0.9544, device='cuda:0'),
#   tensor(0.9608, device='cuda:0'),
#   tensor(0.9587, device='cuda:0'),
#   tensor(0.9631, device='cuda:0'),
#   tensor(0.9630, device='cuda:0')],
#  'valid_loss': [0.32319414011529973,
#   0.20784199771446152,
#   0.14483240669643557,
#   0.15317249806547487,
#   0.27092776709311717,
#   0.21488497960003647,
#   0.12041504739003407,
#   0.1399457753208038,
#   0.3259283387278383,
#   0.13702257649620642],
#  'valid_acc': [90.58601871101871,
#   92.73648648648648,
#   93.87993762993763,
#   94.13331600831602,
#   88.39007276507277,
#   91.85291060291061,
#   95.4002079002079,
#   95.23128898128898,
#   86.239604989605,
#   95.31574844074844],
#  'valid_f1': [tensor(0.7276, device='cuda:0'),
#   tensor(0.7346, device='cuda:0'),
#   tensor(0.7397, device='cuda:0'),
#   tensor(0.7495, device='cuda:0'),
#   tensor(0.6937, device='cuda:0'),
#   tensor(0.7145, device='cuda:0'),
#   tensor(0.7463, device='cuda:0'),
#   tensor(0.7388, device='cuda:0'),
#   tensor(0.6795, device='cuda:0'),
#   tensor(0.7499, device='cuda:0')]}

# %% [markdown]
# #### Graphs

# %%
plot_loss_curves(model_10_results)

# %%
plot_loss_curves(model_11_results)

# %%
plot_loss_curves(model_12_results)

# %% [markdown]
# ### f. CNN - 2 L.L.

# %% [markdown]
# #### Setting up model

# %%
#Number of nodes per layer: 5
torch.manual_seed(42)

model_13 = XRAYS_CNN2(input_shape=1, # 1 colour channel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_13.to(device)
# Out:
# XRAYS_CNN2(
#   (block_1): Sequential(
#     (0): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=128000, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
optimizer_13 = torch.optim.SGD(params=model_13.parameters(), lr=0.01)

# %% [markdown]
# #### Training

# %%
#Set number of epochs
NUM_EPOCHS = 10

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# Train model
model_13_results = train(model=model_13,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_13,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.58909 | Train accuracy: 72.90% | Train F1: 0.84
# Validation loss: 0.55941 | Validation accuracy: 74.32%
#  | Validation F1: 0.75
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.49356 | Train accuracy: 77.05% | Train F1: 0.86
# Validation loss: 0.31502 | Validation accuracy: 85.39%
#  | Validation F1: 0.75
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.28876 | Train accuracy: 88.15% | Train F1: 0.92
# Validation loss: 0.20675 | Validation accuracy: 92.87%
#  | Validation F1: 0.73
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.22879 | Train accuracy: 91.03% | Train F1: 0.94
# Validation loss: 0.20988 | Validation accuracy: 91.09%
#  | Validation F1: 0.75
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.22721 | Train accuracy: 90.75% | Train F1: 0.94
# Validation loss: 0.39953 | Validation accuracy: 81.85%
#  | Validation F1: 0.65
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.22774 | Train accuracy: 90.31% | Train F1: 0.93
# Validation loss: 0.37179 | Validation accuracy: 83.75%
#  | Validation F1: 0.66
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.20296 | Train accuracy: 91.63% | Train F1: 0.94
# Validation loss: 0.16462 | Validation accuracy: 94.05%
#  | Validation F1: 0.74
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.19839 | Train accuracy: 91.98% | Train F1: 0.94
# Validation loss: 0.19320 | Validation accuracy: 92.61%
#  | Validation F1: 0.73
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.20165 | Train accuracy: 91.86% | Train F1: 0.94
# Validation loss: 0.24258 | Validation accuracy: 89.99%
#  | Validation F1: 0.71
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.18603 | Train accuracy: 92.80% | Train F1: 0.95
# Validation loss: 0.17684 | Validation accuracy: 93.37%
#  | Validation F1: 0.75

# %% [markdown]
# #### Results

# %%
model_13_results
# Out:
# {'train_loss': [0.5890887349378318,
#   0.4935565566411242,
#   0.2887615416548215,
#   0.22878996637882665,
#   0.22720777822542004,
#   0.2277354943798855,
#   0.20295696839457378,
#   0.19838680878456216,
#   0.20165220223134384,
#   0.18602932772773784],
#  'train_acc': [72.90414663461539,
#   77.0526592548077,
#   88.14791165865384,
#   91.02877103365384,
#   90.7489483173077,
#   90.31137319711539,
#   91.6259765625,
#   91.98091947115384,
#   91.85884915865384,
#   92.7978515625],
#  'train_f1': [tensor(0.8408, device='cuda:0'),
#   tensor(0.8621, device='cuda:0'),
#   tensor(0.9177, device='cuda:0'),
#   tensor(0.9381, device='cuda:0'),
#   tensor(0.9355, device='cuda:0'),
#   tensor(0.9333, device='cuda:0'),
#   tensor(0.9414, device='cuda:0'),
#   tensor(0.9436, device='cuda:0'),
#   tensor(0.9441, device='cuda:0'),
#   tensor(0.9500, device='cuda:0')],
#  'valid_loss': [0.5594122031250516,
#   0.3150186626290953,
#   0.2067484722749607,
#   0.20987677523815954,
#   0.3995304521475289,
#   0.3717857158264598,
#   0.16461996547877789,
#   0.19319718411645373,
#   0.24257640168070793,
#   0.17684263869415265],
#  'valid_acc': [74.32432432432432,
#   85.38851351351352,
#   92.86642411642411,
#   91.09277546777547,
#   81.85420997920997,
#   83.75129937629939,
#   94.04885654885655,
#   92.61304573804574,
#   89.9948024948025,
#   93.37318087318087],
#  'valid_f1': [tensor(0.7477, device='cuda:0'),
#   tensor(0.7479, device='cuda:0'),
#   tensor(0.7291, device='cuda:0'),
#   tensor(0.7481, device='cuda:0'),
#   tensor(0.6532, device='cuda:0'),
#   tensor(0.6636, device='cuda:0'),
#   tensor(0.7431, device='cuda:0'),
#   tensor(0.7270, device='cuda:0'),
#   tensor(0.7087, device='cuda:0'),
#   tensor(0.7490, device='cuda:0')]}

# %% [markdown]
# #### Graphs

# %%
plot_loss_curves(model_13_results)

# %% [markdown]
# ***
# ### g. Using **weighed loss function**
# ***

# %% [markdown]
# #### Setting up models

# %%
#Linear
torch.manual_seed(42)

#3 linear layers
#5 nodes
model_14 = XRAYS_linear2(input_shape=409600, # one for every pixel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_14.to(device)
# Out:
# XRAYS_linear2(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
optimizer_14 = torch.optim.SGD(params=model_14.parameters(), lr=0.0001)

# %%
#Non-linear
torch.manual_seed(42)

# 2 linear layers
# 10 nodes
model_15 = XRAYS_nonlinear(input_shape=409600, # one for every pixel
    hidden_units=20, # how many units in the hidden layer
    output_shape=1
)
model_15.to(device)
# Out:
# XRAYS_nonlinear(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=20, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=20, out_features=1, bias=True)
#     (4): ReLU()
#   )
# )

# %%
optimizer_15 = torch.optim.SGD(params=model_15.parameters(), lr=0.0001)

# %%
#CNN
torch.manual_seed(42)

# 1 linear layer
# 5 nodes
model_16 = XRAYS_CNN(input_shape=1, # 1 colour channel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_16.to(device)
# Out:
# XRAYS_CNN(
#   (block_1): Sequential(
#     (0): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=128000, out_features=1, bias=True)
#   )
# )

# %%
optimizer_16 = torch.optim.SGD(params=model_16.parameters(), lr=0.01)

# %% [markdown]
# #### Training

# %%
#Set number of epochs
NUM_EPOCHS = 10

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

#Using weighed loss function
# Train model
model_14_results = train(model=model_14,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_14,
                        loss_fn=loss_fn_weighed,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.34145 | Train accuracy: 67.90% | Train F1: 0.67
# Validation loss: 0.30210 | Validation accuracy: 86.12%
#  | Validation F1: 0.69
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.28649 | Train accuracy: 88.42% | Train F1: 0.92
# Validation loss: 0.28143 | Validation accuracy: 92.70%
#  | Validation F1: 0.73
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.28360 | Train accuracy: 88.67% | Train F1: 0.93
# Validation loss: 0.26694 | Validation accuracy: 89.53%
#  | Validation F1: 0.75

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

#Using weighed loss function
# Train model
model_16_results = train(model=model_16,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_16,
                        loss_fn=loss_fn_weighed,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37826 | Train accuracy: 51.76% | Train F1: 0.46
# Validation loss: 0.35432 | Validation accuracy: 74.94%
#  | Validation F1: 0.60
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.29391 | Train accuracy: 81.06% | Train F1: 0.86
# Validation loss: 0.19169 | Validation accuracy: 89.27%
#  | Validation F1: 0.74
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.17120 | Train accuracy: 86.61% | Train F1: 0.90
# Validation loss: 0.12421 | Validation accuracy: 88.69%
#  | Validation F1: 0.70
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.13838 | Train accuracy: 88.83% | Train F1: 0.92
# Validation loss: 0.11069 | Validation accuracy: 93.29%
#  | Validation F1: 0.73
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.14089 | Train accuracy: 89.55% | Train F1: 0.92
# Validation loss: 0.29591 | Validation accuracy: 65.90%
#  | Validation F1: 0.53
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.14121 | Train accuracy: 89.03% | Train F1: 0.92
# Validation loss: 0.36323 | Validation accuracy: 60.91%
#  | Validation F1: 0.48
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.12675 | Train accuracy: 89.94% | Train F1: 0.93
# Validation loss: 0.10444 | Validation accuracy: 92.70%
#  | Validation F1: 0.73
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.12440 | Train accuracy: 90.53% | Train F1: 0.93
# Validation loss: 0.12226 | Validation accuracy: 87.68%
#  | Validation F1: 0.69
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.12580 | Train accuracy: 90.25% | Train F1: 0.93
# Validation loss: 0.17291 | Validation accuracy: 79.03%
#  | Validation F1: 0.63
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.11863 | Train accuracy: 90.36% | Train F1: 0.93
# Validation loss: 0.11740 | Validation accuracy: 94.13%
#  | Validation F1: 0.74

# %% [markdown]
# #### Results

# %%
model_14_results
# Out:
# {'train_loss': [0.3414453259902075,
#   0.2909565673908219,
#   0.25844730716198683,
#   0.2358043355634436,
#   0.22032395645510405,
#   0.20813529449515045,
#   0.19647895521484315,
#   0.18945199472364038,
#   0.18315589014673606,
#   0.1767220739275217],
#  'train_acc': [67.8955078125,
#   84.31678185096153,
#   86.07459435096153,
#   86.09900841346153,
#   86.80701622596153,
#   87.1112530048077,
#   87.7685546875,
#   87.7704326923077,
#   87.90564903846153,
#   88.26998197115384],
#  'train_f1': [tensor(0.6695, device='cuda:0'),
#   tensor(0.8831, device='cuda:0'),
#   tensor(0.8966, device='cuda:0'),
#   tensor(0.8971, device='cuda:0'),
#   tensor(0.9035, device='cuda:0'),
#   tensor(0.9059, device='cuda:0'),
#   tensor(0.9107, device='cuda:0'),
#   tensor(0.9094, device='cuda:0'),
#   tensor(0.9119, device='cuda:0'),
#   tensor(0.9140, device='cuda:0')],
#  'valid_loss': [0.30209579822179433,
#   0.26172786266417114,
#   0.23659659358295235,
#   0.2162093922898576,
#   0.21129441623752182,
#   0.19308132557450114,
#   0.18247438202033173,
#   0.17911593273684784,
#   0.17551867200716123,
#   0.16163767813830762],
#  'valid_acc': [86.11616424116424,
#   90.16372141372142,
#   85.35602910602911,
#   88.05223492723493,
#   81.89319126819127,
#   86.66190228690229,
#   88.3056133056133,
#   85.8173076923077,
#   85.31055093555094,
#   91.00831600831602],
#  'valid_f1': [tensor(0.6865, device='cuda:0'),
#   tensor(0.7242, device='cuda:0'),
#   tensor(0.6818, device='cuda:0'),
#   tensor(0.6998, device='cuda:0'),
#   tensor(0.6515, device='cuda:0'),
#   tensor(0.6886, device='cuda:0'),
#   tensor(0.6999, device='cuda:0'),
#   tensor(0.6803, device='cuda:0'),
#   tensor(0.6767, device='cuda:0'),
#   tensor(0.7167, device='cuda:0')]}

# %%
model_15_results
# Out:
# {'train_loss': [0.36111466446891427,
#   0.3375690442044288,
#   0.32234160508960485,
#   0.31101372616831213,
#   0.3041445536073297,
#   0.2983997323317453,
#   0.29263182904105633,
#   0.28980344819137827,
#   0.2864938562270254,
#   0.28360459045507014],
#  'train_acc': [75.80942007211539,
#   81.3495342548077,
#   83.46228966346153,
#   85.1337139423077,
#   86.00135216346153,
#   86.84457632211539,
#   87.4530498798077,
#   87.95447716346153,
#   88.41834435096153,
#   88.671875],
#  'train_f1': [tensor(0.8475, device='cuda:0'),
#   tensor(0.8844, device='cuda:0'),
#   tensor(0.8954, device='cuda:0'),
#   tensor(0.9052, device='cuda:0'),
#   tensor(0.9099, device='cuda:0'),
#   tensor(0.9148, device='cuda:0'),
#   tensor(0.9183, device='cuda:0'),
#   tensor(0.9204, device='cuda:0'),
#   tensor(0.9241, device='cuda:0'),
#   tensor(0.9255, device='cuda:0')],
#  'valid_loss': [0.33906020626828476,
#   0.31601679123736715,
#   0.3052880014922168,
#   0.29356507856298136,
#   0.29729579671009165,
#   0.2913421746846792,
#   0.27699478836478414,
#   0.27824617136974594,
#   0.2814312937694627,
#   0.26694254899347153],
#  'valid_acc': [86.57094594594595,
#   80.15202702702703,
#   89.35810810810811,
#   86.14864864864865,
#   92.22972972972973,
#   92.22972972972973,
#   89.61148648648648,
#   92.14527027027027,
#   92.6975051975052,
#   89.52702702702703],
#  'valid_f1': [tensor(0.7464, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7467, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7353, device='cuda:0'),
#   tensor(0.7353, device='cuda:0'),
#   tensor(0.7474, device='cuda:0'),
#   tensor(0.7414, device='cuda:0'),
#   tensor(0.7333, device='cuda:0'),
#   tensor(0.7474, device='cuda:0')]}

# %%
model_16_results

# %% [markdown]
# #### Graph

# %%
plot_loss_curves(model_14_results)

# %%
plot_loss_curves(model_15_results)

# %%
plot_loss_curves(model_16_results)

# %% [markdown]
# ***
# ### h. Changing **optimizer**
# ***

# %% [markdown]
# #### Setting up models

# %%
#Linear
torch.manual_seed(42)

#3 linear layers
#5 nodes
model_17 = XRAYS_linear2(input_shape=409600, # one for every pixel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_17.to(device)
# Out:
# XRAYS_linear2(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
optimizer_17 = torch.optim.Adam(params=model_17.parameters(), lr=0.0001)

# %%
#Non-linear
torch.manual_seed(42)

# 2 linear layers
# 10 nodes
model_18 = XRAYS_nonlinear(input_shape=409600, # one for every pixel
    hidden_units=20, # how many units in the hidden layer
    output_shape=1
)
model_18.to(device)
# Out:
# XRAYS_nonlinear(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=20, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=20, out_features=1, bias=True)
#     (4): ReLU()
#   )
# )

# %%
optimizer_18 = torch.optim.Adam(params=model_18.parameters(), lr=0.0001)

# %%
#CNN
torch.manual_seed(42)

# 1 linear layer
# 5 nodes
model_19 = XRAYS_CNN(input_shape=1, # 1 colour channel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_19.to(device)
# Out:
# XRAYS_CNN(
#   (block_1): Sequential(
#     (0): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=128000, out_features=1, bias=True)
#   )
# )

# %%
optimizer_19 = torch.optim.Adam(params=model_19.parameters(), lr=0.01)

# %% [markdown]
# #### Training

# %%
#Set number of epochs
NUM_EPOCHS = 10

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

#Using weighed loss function
# Train model
model_17_results = train(model=model_17,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_17,
                        loss_fn=loss_fn_weighed,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.36759 | Train accuracy: 79.21% | Train F1: 0.81
# Validation loss: 0.13337 | Validation accuracy: 93.54%
#  | Validation F1: 0.75
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.13643 | Train accuracy: 89.51% | Train F1: 0.92
# Validation loss: 0.09765 | Validation accuracy: 91.85%
#  | Validation F1: 0.71
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.13796 | Train accuracy: 89.63% | Train F1: 0.92
# Validation loss: 0.10896 | Validation accuracy: 94.72%
#  | Validation F1: 0.74
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.16533 | Train accuracy: 89.06% | Train F1: 0.92
# Validation loss: 0.10432 | Validation accuracy: 94.30%
#  | Validation F1: 0.74
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.12238 | Train accuracy: 91.30% | Train F1: 0.94
# Validation loss: 0.33574 | Validation accuracy: 69.45%
#  | Validation F1: 0.56
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.16287 | Train accuracy: 89.39% | Train F1: 0.92
# Validation loss: 0.23230 | Validation accuracy: 77.72%
#  | Validation F1: 0.62
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.15710 | Train accuracy: 90.26% | Train F1: 0.93
# Validation loss: 0.09872 | Validation accuracy: 92.19%
#  | Validation F1: 0.72
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.17436 | Train accuracy: 88.87% | Train F1: 0.91
# Validation loss: 0.13000 | Validation accuracy: 94.81%
#  | Validation F1: 0.74
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.10288 | Train accuracy: 93.18% | Train F1: 0.95
# Validation loss: 0.13935 | Validation accuracy: 87.38%
#  | Validation F1: 0.69
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.13151 | Train accuracy: 91.41% | Train F1: 0.94
# Validation loss: 0.18421 | Validation accuracy: 93.80%
#  | Validation F1: 0.75

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

#Using weighed loss function
# Train model
model_18_results = train(model=model_18,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_18,
                        loss_fn=loss_fn_weighed,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37495 | Train accuracy: 27.73% | Train F1: 0.01
# Validation loss: 0.36859 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37463 | Train accuracy: 27.06% | Train F1: 0.00
# Validation loss: 0.36859 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37494 | Train accuracy: 27.13% | Train F1: 0.00
# Validation loss: 0.36859 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37463 | Train accuracy: 27.06% | Train F1: 0.00
# Validation loss: 0.36859 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37463 | Train accuracy: 27.06% | Train F1: 0.00
# Validation loss: 0.36859 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37479 | Train accuracy: 27.10% | Train F1: 0.00
# Validation loss: 0.36859 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37463 | Train accuracy: 27.06% | Train F1: 0.00
# Validation loss: 0.36859 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37479 | Train accuracy: 27.10% | Train F1: 0.00
# Validation loss: 0.36859 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37479 | Train accuracy: 27.10% | Train F1: 0.00
# Validation loss: 0.36859 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37479 | Train accuracy: 27.10% | Train F1: 0.00
# Validation loss: 0.36859 | Validation accuracy: 25.68%
#  | Validation F1: 0.00

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

#Using weighed loss function
# Train model
model_19_results = train(model=model_19,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_19,
                        loss_fn=loss_fn_weighed,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.75518 | Train accuracy: 69.93% | Train F1: 0.78
# Validation loss: 0.36835 | Validation accuracy: 74.32%
#  | Validation F1: 0.75
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37465 | Train accuracy: 64.90% | Train F1: 0.69
# Validation loss: 0.36915 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37509 | Train accuracy: 32.73% | Train F1: 0.10
# Validation loss: 0.36843 | Validation accuracy: 74.32%
#  | Validation F1: 0.75
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37475 | Train accuracy: 44.18% | Train F1: 0.32
# Validation loss: 0.36842 | Validation accuracy: 74.32%
#  | Validation F1: 0.75
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37466 | Train accuracy: 69.64% | Train F1: 0.77
# Validation loss: 0.36932 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37501 | Train accuracy: 28.56% | Train F1: 0.03
# Validation loss: 0.36888 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37485 | Train accuracy: 33.24% | Train F1: 0.12
# Validation loss: 0.36832 | Validation accuracy: 74.32%
#  | Validation F1: 0.75
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37494 | Train accuracy: 69.63% | Train F1: 0.78
# Validation loss: 0.36913 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37513 | Train accuracy: 42.67% | Train F1: 0.30
# Validation loss: 0.36864 | Validation accuracy: 25.68%
#  | Validation F1: 0.00
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37498 | Train accuracy: 34.13% | Train F1: 0.15
# Validation loss: 0.36851 | Validation accuracy: 74.32%
#  | Validation F1: 0.75

# %% [markdown]
# #### Results

# %%
model_17_results
# Out:
# {'train_loss': [0.36758790476596914,
#   0.13642641897604335,
#   0.13795559492427856,
#   0.16532983969227644,
#   0.1223807254282292,
#   0.16287253530026646,
#   0.15710167712677503,
#   0.17436105454726203,
#   0.10287961794711009,
#   0.1315121184452437],
#  'train_acc': [79.21236478365384,
#   89.50570913461539,
#   89.6259014423077,
#   89.0643780048077,
#   91.29920372596153,
#   89.39302884615384,
#   90.2587890625,
#   88.8690655048077,
#   93.17908653846153,
#   91.40625],
#  'train_f1': [tensor(0.8089, device='cuda:0'),
#   tensor(0.9210, device='cuda:0'),
#   tensor(0.9233, device='cuda:0'),
#   tensor(0.9166, device='cuda:0'),
#   tensor(0.9359, device='cuda:0'),
#   tensor(0.9187, device='cuda:0'),
#   tensor(0.9264, device='cuda:0'),
#   tensor(0.9139, device='cuda:0'),
#   tensor(0.9501, device='cuda:0'),
#   tensor(0.9360, device='cuda:0')],
#  'valid_loss': [0.1333653876759313,
#   0.0976506141895378,
#   0.10896000701531365,
#   0.10431866823519403,
#   0.33573764361239766,
#   0.2322963561258606,
#   0.098721339593868,
#   0.1300038219102331,
#   0.13935437964627873,
#   0.18421209554150197],
#  'valid_acc': [93.54209979209979,
#   91.85291060291061,
#   94.72453222453223,
#   94.30223492723493,
#   69.44516632016632,
#   77.72219334719334,
#   92.19074844074844,
#   94.80899168399169,
#   87.37655925155926,
#   93.79547817047818],
#  'valid_f1': [tensor(0.7464, device='cuda:0'),
#   tensor(0.7144, device='cuda:0'),
#   tensor(0.7432, device='cuda:0'),
#   tensor(0.7405, device='cuda:0'),
#   tensor(0.5567, device='cuda:0'),
#   tensor(0.6204, device='cuda:0'),
#   tensor(0.7194, device='cuda:0'),
#   tensor(0.7449, device='cuda:0'),
#   tensor(0.6866, device='cuda:0'),
#   tensor(0.7502, device='cuda:0')]}

# %%
model_18_results
# Out:
# {'train_loss': [0.3749487604945898,
#   0.37463156832382083,
#   0.3749432028271258,
#   0.3746315680909902,
#   0.37463156832382083,
#   0.3747873848769814,
#   0.37463156785815954,
#   0.37478738534264266,
#   0.37478738534264266,
#   0.3747873855754733],
#  'train_acc': [27.730618990384617,
#   27.06017127403846,
#   27.13153545673077,
#   27.06017127403846,
#   27.06017127403846,
#   27.095853365384617,
#   27.06017127403846,
#   27.095853365384617,
#   27.095853365384617,
#   27.095853365384617],
#  'train_f1': [tensor(0.0129, device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0')],
#  'valid_loss': [0.3685856936751185,
#   0.3685856936751185,
#   0.3685856936751185,
#   0.3685856936751185,
#   0.3685856936751185,
#   0.3685856936751185,
#   0.3685856936751185,
#   0.3685856936751185,
#   0.3685856936751185,
#   0.3685856936751185],
#  'valid_acc': [25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677,
#   25.675675675675677],
#  'valid_f1': [tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0'),
#   tensor(0., device='cuda:0')]}

# %%
model_19_results

# %% [markdown]
# #### Graphs

# %%
plot_loss_curves(model_17_results)

# %%
plot_loss_curves(model_18_results)

# %%
plot_loss_curves(model_19_results)

# %% [markdown]
# ***
# ###  i. Increasing number of **epochs** - loss function not weighed
# ***

# %% [markdown]
# #### Setting up models

# %%
#Linear
torch.manual_seed(42)

#3 linear layers
#5 nodes
model_20 = XRAYS_linear2(input_shape=409600, # one for every pixel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_20.to(device)
# Out:
# XRAYS_linear2(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
optimizer_20 = torch.optim.SGD(params=model_20.parameters(), lr=0.0001)

# %%
#Non-linear
torch.manual_seed(42)

# 2 linear layers
# 10 nodes
model_21 = XRAYS_nonlinear(input_shape=409600, # one for every pixel
    hidden_units=20, # how many units in the hidden layer
    output_shape=1
)
model_21.to(device)
# Out:
# XRAYS_nonlinear(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=20, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=20, out_features=1, bias=True)
#     (4): ReLU()
#   )
# )

# %%
optimizer_21 = torch.optim.SGD(params=model_21.parameters(), lr=0.0001)

# %%
#CNN
torch.manual_seed(42)

# 1 linear layer
# 5 hidden units
model_22 = XRAYS_CNN(input_shape=1, # 1 colour channel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_22.to(device)
# Out:
# XRAYS_CNN(
#   (block_1): Sequential(
#     (0): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=128000, out_features=1, bias=True)
#   )
# )

# %%
optimizer_22 = torch.optim.SGD(params=model_22.parameters(), lr=0.01)

# %% [markdown]
# #### Training

# %%
#Set number of epochs
NUM_EPOCHS = 50

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

#Using weighed loss function
# Train model
model_20_results = train(model=model_20,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_20,
                        loss_fn=loss_fn,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.52164 | Train accuracy: 73.37% | Train F1: 0.84
# Validation loss: 0.44261 | Validation accuracy: 77.36%
#  | Validation F1: 0.75
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.42572 | Train accuracy: 80.20% | Train F1: 0.88
# Validation loss: 0.37383 | Validation accuracy: 82.09%
#  | Validation F1: 0.75
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.37115 | Train accuracy: 85.08% | Train F1: 0.90
# Validation loss: 0.33325 | Validation accuracy: 89.27%
#  | Validation F1: 0.74
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.33607 | Train accuracy: 87.55% | Train F1: 0.92
# Validation loss: 0.30199 | Validation accuracy: 89.27%
#  | Validation F1: 0.75
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.31314 | Train accuracy: 88.54% | Train F1: 0.92
# Validation loss: 0.29945 | Validation accuracy: 91.94%
#  | Validation F1: 0.73
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.29589 | Train accuracy: 89.49% | Train F1: 0.93
# Validation loss: 0.27286 | Validation accuracy: 92.28%
#  | Validation F1: 0.74
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.27854 | Train accuracy: 89.88% | Train F1: 0.93
# Validation loss: 0.25618 | Validation accuracy: 92.28%
#  | Validation F1: 0.74
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.26891 | Train accuracy: 90.63% | Train F1: 0.94
# Validation loss: 0.25301 | Validation accuracy: 92.70%
#  | Validation F1: 0.74
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.26051 | Train accuracy: 90.64% | Train F1: 0.94
# Validation loss: 0.25220 | Validation accuracy: 92.87%
#  | Validation F1: 0.73
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.25124 | Train accuracy: 90.94% | Train F1: 0.94
# Validation loss: 0.22604 | Validation accuracy: 92.44%
#  | Validation F1: 0.74
# Epoch: 10
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.24177 | Train accuracy: 91.31% | Train F1: 0.94
# Validation loss: 0.22268 | Validation accuracy: 91.89%
#  | Validation F1: 0.75
# Epoch: 11
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0
#   92.46920072115384,
#   92.37154447115384,
#   92.44478665865384,
#   92.73775540865384,
#   92.85982572115384,
#   92.68892728365384,
#   92.7020733173077,
#   92.87109375,
#   92.88423978365384,
#   92.9931640625,
#   92.8973858173077,
#   93.0908203125,
#   93.2861328125,
#   92.9950420673077,
#   93.10396634615384,
#   93.3124248798077,
#   93.44576322115384,
#   93.310546875,
#   92.87484975961539,
#   93.26171875,
#   93.3837890625,
#   93.12838040865384,
#   93.3837890625,
#   93.2635967548077,
#   93.1903545673077,
#   93.408203125,
#   93.5546875,
#   93.39693509615384,
#   93.603515625,
#   93.6053936298077,
#   93.50961538461539,
#   93.4100811298077,
#   93.6053936298077],
#  'train_f1': [tensor(0.8381, device='cuda:0'),
#   tensor(0.8783, device='cuda:0'),
#   tensor(0.9044, device='cuda:0'),
#   tensor(0.9188, device='cuda:0'),
#   tensor(0.9235, device='cuda:0'),
#   tensor(0.9300, device='cuda:0'),
#   tensor(0.9322, device='cuda:0'),
#   tensor(0.9360, device='cuda:0'),
#   tensor(0.9368, device='cuda:0'),
#   tensor(0.9385, device='cuda:0'),
#   tensor(0.9401, device='cuda:0'),
#   tensor(0.9414, device='cuda:0'),
#   tensor(0.9428, device='cuda:0'),
#   tensor(0.9435, device='cuda:0'),
#   tensor(0.9439, device='cuda:0'),
#   tensor(0.9449, device='cuda:0'),
#   tensor(0.9476, device='cuda:0'),
#   tensor(0.9486, device='cuda:0'),
#   tensor(0.9478, device='cuda:0'),
#   tensor(0.9486, device='cuda:0'),
#   tensor(0.9506, device='cuda:0'),
#   tensor(0.9513, device='cuda:0'),
#   tensor(0.9497, device='cuda:0'),
#   tensor(0.9495, device='cuda:0'),
#   tensor(0.9510, device='cuda:0'),
#   tensor(0.9505, device='cuda:0'),
#   tensor(0.9523, device='cuda:0'),
#   tensor(0.9509, device='cuda:0'),
#   tensor(0.9520, device='cuda:0'),
#   tensor(0.9541, device='cuda:0'),
#   tensor(0.9514, device='cuda:0'),
#   tensor(0.9524, device='cuda:0'),
#   tensor(0.9530, device='cuda:0'),
#   tensor(0.9548, device='cuda:0'),
#   tensor(0.9538, device='cuda:0'),
#   tensor(0.9507, device='cuda:0'),
#   tensor(0.9534, device='cuda:0'),
#   tensor(0.9546, device='cuda:0'),
#   tensor(0.9521, device='cuda:0'),
#   tensor(0.9547, device='cuda:0'),
#   tensor(0.9532, device='cuda:0'),
#   tensor(0.9528, device='cuda:0'),
#   tensor(0.9544, device='cuda:0'),
#   tensor(0.9556, device='cuda:0'),
#   tensor(0.9546, device='cuda:0'),
#   tensor(0.9559, device='cuda:0'),
#   tensor(0.9561, device='cuda:0'),
#   tensor(0.9547, device='cuda:0'),
#   tensor(0.9547, device='cuda:0'),
#   tensor(0.9556, device='cuda:0')],
#  'valid_loss': [0.4426140322073086,
#   0.3738300506327603,
#   0.3332521609357885,
#   0.3019921807823954,
#   0.2994484402037956,
#   0.27286390839396296,
#   0.256176163215895,
#   0.25301258104878505,
#   0.2522024113584209,
#   0.22604077812787648,
#   0.22268318888303396,
#   0.2155240810400731,
#   0.21042929247424408,
#   0.2063382620344291,
#   0.22334577545926376,
#   0.19750403834355845,
#   0.19382275338913943,
#   0.2001510743756552,
#   0.18849537380643794,
#   0.18903355521930232,
#   0.1886346412671579,
#   0.1978596259613295,
#   0.18227000061321902,
#   0.17769407339998194,
#   0.1819942780845874,
#   0.19571697248800382,
#   0.18486842593631228,
#   0.1752591936572178,
#   0.1794055158624778,
#   0.16999590688863317,
#   0.18044306478790334,
#   0.184832201012083,
#   0.16701969897022118,
#   0.16626794455019203,
#   0.16435036355176488,
#   0.16960180772317424,
#   0.21811919840606483,
#   0.16806000954396016,
#   0.1639897538399374,
#   0.16204945138982824,
#   0.16649052087922353,
#   0.1593291713176547,
#   0.1587202670807774,
#   0.1580241825935003,
#   0.15771030866213748,
#   0.1570354512817151,
#   0.16109119073764697,
#   0.17442542586374926,
#   0.17142689570381836,
#   0.15519992528936347],
#  'valid_acc': [77.36486486486487,
#   82.0945945945946,
#   89.27364864864865,
#   89.27364864864865,
#   91.93737006237006,
#   92.2752079002079,
#   92.2752079002079,
#   92.6975051975052,
#   92.86642411642411,
#   92.44412681912682,
#   91.89189189189189,
#   92.61304573804574,
#   92.02182952182952,
#   92.2752079002079,
#   93.1198024948025,
#   92.6975051975052,
#   93.20426195426195,
#   93.54209979209979,
#   93.37318087318087,
#   93.54209979209979,
#   93.71101871101871,
#   93.45764033264034,
#   93.87993762993763,
#   93.71101871101871,
#   93.62655925155926,
#   93.79547817047818,
#   93.87993762993763,
#   93.9643970893971,
#   93.71101871101871,
#   93.87993762993763,
#   93.9643970893971,
#   93.71101871101871,
#   94.30223492723493,
#   94.04885654885655,
#   94.21777546777547,
#   93.87993762993763,
#   91.85291060291061,
#   93.9643970893971,
#   94.30223492723493,
#   94.30223492723493,
#   93.87993762993763,
#   94.47115384615385,
#   94.47115384615385,
#   94.47115384615385,
#   94.64007276507277,
#   94.30223492723493,
#   94.04885654885655,
#   94.13331600831602,
#   92.6975051975052,
#   94.64007276507277],
#  'valid_f1': [tensor(0.7473, device='cuda:0'),
#   tensor(0.7477, device='cuda:0'),
#   tensor(0.7434, device='cuda:0'),
#   tensor(0.7460, device='cuda:0'),
#   tensor(0.7320, device='cuda:0'),
#   tensor(0.7383, device='cuda:0'),
#   tensor(0.7405, device='cuda:0'),
#   tensor(0.7351, device='cuda:0'),
#   tensor(0.7311, device='cuda:0'),
#   tensor(0.7445, device='cuda:0'),
#   tensor(0.7479, device='cuda:0'),
#   tensor(0.7392, device='cuda:0'),
#   tensor(0.7459, device='cuda:0'),
#   tensor(0.7461, device='cuda:0'),
#   tensor(0.7307, device='cuda:0'),
#   tensor(0.7451, device='cuda:0'),
#   tensor(0.7445, device='cuda:0'),
#   tensor(0.7356, device='cuda:0'),
#   tensor(0.7423, device='cuda:0'),
#   tensor(0.7379, device='cuda:0'),
#   tensor(0.7374, device='cuda:0'),
#   tensor(0.7334, device='cuda:0'),
#   tensor(0.7388, device='cuda:0'),
#   tensor(0.7432, device='cuda:0'),
#   tensor(0.7370, device='cuda:0'),
#   tensor(0.7334, device='cuda:0'),
#   tensor(0.7356, device='cuda:0'),
#   tensor(0.7392, device='cuda:0'),
#   tensor(0.7356, device='cuda:0'),
#   tensor(0.7458, device='cuda:0'),
#   tensor(0.7356, device='cuda:0'),
#   tensor(0.7338, device='cuda:0'),
#   tensor(0.7414, device='cuda:0'),
#   tensor(0.7462, device='cuda:0'),
#   tensor(0.7419, device='cuda:0'),
#   tensor(0.7375, device='cuda:0'),
#   tensor(0.7175, device='cuda:0'),
#   tensor(0.7379, device='cuda:0'),
#   tensor(0.7397, device='cuda:0'),
#   tensor(0.7406, device='cuda:0'),
#   tensor(0.7375, device='cuda:0'),
#   tensor(0.7436, device='cuda:0'),
#   tensor(0.7436, device='cuda:0'),
#   tensor(0.7428, device='cuda:0'),
#   tensor(0.7445, device='cuda:0'),
#   tensor(0.7419, device='cuda:0'),
#   tensor(0.7384, device='cuda:0'),
#   tensor(0.7356, device='cuda:0'),
#   tensor(0.7486, device='cuda:0'),
#   tensor(0.7432, device='cuda:0')]}

# %%
model_21_results
# Out:
# {'train_loss': [0.4158920787740499,
#   0.3986310597974807,
#   0.3860037624835968,
#   0.3751428098184988,
#   0.3676797916414216,
#   0.36114027025178075,
#   0.3532266115071252,
#   0.34994891739916056,
#   0.3458071049535647,
#   0.34087720687966794,
#   0.33419842331204563,
#   0.3320601899176836,
#   0.3287053907988593,
#   0.3261321991449222,
#   0.3242193644400686,
#   0.32053256407380104,
#   0.31781225523445755,
#   0.3169776634313166,
#   0.31491620116867125,
#   0.312470487668179,
#   0.3105607923353091,
#   0.31020895682740957,
#   0.3089517313055694,
#   0.30781751638278365,
#   0.3065613337093964,
#   0.30543252953793854,
#   0.3043031741399318,
#   0.3026979878777638,
#   0.30224050558172166,
#   0.30049777909880504,
#   0.30127606994938105,
#   0.2989615889964625,
#   0.2990747414296493,
#   0.297362671000883,
#   0.2971472651697695,
#   0.2977704224176705,
#   0.29619283200008795,
#   0.29662416328210384,
#   0.29531401628628373,
#   0.2936526856501587,
#   0.294782088836655,
#   0.29305063374340534,
#   0.2916937427362427,
#   0.29110816249158233,
#   0.2917525601806119,
#   0.2911370793590322,
#   0.2907328213332221,
#   0.29219805949833244,
#   0.2894558549160138,
#   0.2894972865469754],
#  'train_acc': [78.70154747596153,
#   81.1542217548077,
#   82.02185997596153,
#   83.1317608173077,
#   83.99939903846153,
#   84.69613882211539,
#   85.68209134615384,
#   85.97693810096153,
#   86.34314903846153,
#   87.1112530048077,
#   87.2314453125,
#   87.57699819711539,
#   88.22115384615384,
#   88.46529447115384,
#   88.44275841346153,
#   89.10006009615384,
#   89.208984375,
#   89.4550030048077,
#   89.63716947115384,
#   89.51509915865384,
#   89.93013822115384,
#   90.07662259615384,
#   90.32076322115384,
#   90.3339092548077,
#   90.4071514423077,
#   90.7489483173077,
#   90.57992788461539,
#   90.7733623798077,
#   90.78463040865384,
#   91.2353515625,
#   0.09945812696241774,
#   0.10469238438236061,
#   0.0865015571580443,
#   0.08930597559083253,
#   0.08753188580158167,
#   0.0809015287013608,
#   0.08879242916009389,
#   0.09440554537286516,
#   0.08100345660568564,
#   0.08154789597119816,
#   0.0820242790678094],
#  'train_acc': [72.17172475961539,
#   85.04732572115384,
#   89.75923978365384,
#   91.1884014423077,
#   91.0663311298077,
#   90.70199819711539,
#   91.8701171875,
#   92.29830228365384,
#   92.17623197115384,
#   93.3349609375,
#   93.408203125,
#   93.88521634615384,
#   93.1640625,
#   93.896484375,
#   94.30025540865384,
#   94.56881009615384,
#   94.8486328125,
#   94.76412259615384,
#   95.41015625,
#   95.56978665865384,
#   95.6298828125,
#   95.61861478365384,
#   95.3857421875,
#   80.72603665865384,
#   91.9921875,
#   94.384765625,
#   94.677734375,
#   95.03267728365384,
#   94.8486328125,
#   95.361328125,
#   95.56978665865384,
#   95.91158353365384,
#   96.0223858173077,
#   95.71627103365384,
#   95.22798978365384,
#   96.10689603365384,
#   96.3623046875,
#   96.2646484375,
#   96.20455228365384,
#   96.4599609375,
#   96.2421123798077,
#   96.6064453125,
#   96.484375,
#   96.98580228365384,
#   97.021484375,
#   97.0947265625,
#   96.54634915865384,
#   97.32759915865384,
#   97.13228665865384,
#   96.97265625],
#  'train_f1': [tensor(0.8276, device='cuda:0'),
#   tensor(0.9017, device='cuda:0'),
#   tensor(0.9284, device='cuda:0'),
#   tensor(0.9390, device='cuda:0'),
#   tensor(0.9375, device='cuda:0'),
#   tensor(0.9360, device='cuda:0'),
#   tensor(0.9432, device='cuda:0'),
#   tensor(0.9456, device='cuda:0'),
#   tensor(0.9460, device='cuda:0'),
#   tensor(0.9537, device='cuda:0'),
#   tensor(0.9537, device='cuda:0'),
#   tensor(0.9578, device='cuda:0'),
#   tensor(0.9524, device='cuda:0'),
#   tensor(0.9573, device='cuda:0'),
#   tensor(0.9599, device='cuda:0'),
#   tensor(0.9623, device='cuda:0'),
#   tensor(0.9641, device='cuda:0'),
#   tensor(0.9637, device='cuda:0'),
#   tensor(0.9680, device='cuda:0'),
#   tensor(0.9695, device='cuda:0'),
#   tensor(0.9696, device='cuda:0'),
#   tensor(0.9695, device='cuda:0'),
#   tensor(0.9676, device='cuda:0'),
#   tensor(0.8799, device='cuda:0'),
#   tensor(0.9447, device='cuda:0'),
#   tensor(0.9609, device='cuda:0'),
#   tensor(0.9632, device='cuda:0'),
#   tensor(0.9652, device='cuda:0'),
#   tensor(0.9642, device='cuda:0'),
#   tensor(0.9680, device='cuda:0'),
#   tensor(0.9684, device='cuda:0'),
#   tensor(0.9715, device='cuda:0'),
#   tensor(0.9720, device='cuda:0'),
#   tensor(0.9700, device='cuda:0'),
#   tensor(0.9663, device='cuda:0'),
#   tensor(0.9728, device='cuda:0'),
#   tensor(0.9747, device='cuda:0'),
#   tensor(0.9739, device='cuda:0'),
#   tensor(0.9731, device='cuda:0'),
#   tensor(0.9755, device='cuda:0'),
#   tensor(0.9735, device='cuda:0'),
#   tensor(0.9764, device='cuda:0'),
#   tensor(0.9758, device='cuda:0'),
#   tensor(0.9791, device='cuda:0'),
#   tensor(0.9796, device='cuda:0'),
#   tensor(0.9796, device='cuda:0'),
#   tensor(0.9756, device='cuda:0'),
#   tensor(0.9812, device='cuda:0'),
#   tensor(0.9798, device='cuda:0'),
#   tensor(0.9790, device='cuda:0')],
#  'valid_loss': [0.493143389353881,
#   0.24290347388769323,
#   0.1993322140864424,
#   0.20876281570039085,
#   0.40592436180324165,
#   0.38530803622828946,
#   0.16144362464547157,
#   0.18288910268126307,
#   0.23716659733169787,
#   0.1679529011299884,
#   0.16064273779960098,
#   0.2173288113097786,
#   0.14898798176767053,
#   0.14107058753536358,
#   0.24354587847719322,
#   0.1607013001433901,
#   0.13564372568617802,
#   0.17256223158659162,
#   0.128565874756188,
#   0.1515426695648883,
#   0.12169045192265027,
#   0.3276088238265869,
#   0.12061019095818738,
#   0.20353174853969264,
#   0.1678641014606566,
#   0.13855924024372487,
#   0.1411395984122882,
#   0.11593151439887446,
#   0.11776220597125389,
#   0.1269397354508574,
#   0.13585128187126405,
#   0.13183043101752126,
#   0.3322693617964113,
#   0.132861454895622,
#   0.22905519151607076,
#   0.14554102879923744,
#   0.22249698830214706,
#   0.1360592174066885,
#   0.12565838409638083,
#   0.133158251190105,
#   0.4369903018547071,
#   0.11757413962402859,
#   0.12656732578132604,
#   0.18724935546020247,
#   0.1213519334969287,
#   0.12815340711558992,
#   0.18982093123958219,
#   1.0140696074813604,
#   0.5052570931463404,
#   0.12999649631564278],
#  'valid_acc': [74.40878378378379,
#   89.1891891891892,
#   92.95088357588358,
#   91.26169438669439,
#   81.55535343035343,
#   82.69880457380457,
#   94.13331600831602,
#   93.03534303534303,
#   90.16372141372142,
#   94.04885654885655,
#   93.79547817047818,
#   91.55405405405405,
#   94.47115384615385,
#   94.5556133056133,
#   90.8393970893971,
#   94.21777546777547,
#   94.5556133056133,
#   94.13331600831602,
#   94.97791060291061,
#   94.64007276507277,
#   95.31574844074844,
#   87.12318087318087,
#   95.14682952182952,
#   93.32770270270271,
#   93.62655925155926,
#   94.93243243243244,
#   94.38669438669439,
#   95.35472972972973,
#   95.31574844074844,
#   95.1858108108108,
#   94.97791060291061,
#   95.23128898128898,
#   86.27858627858627,
#   95.01689189189189,
#   91.09277546777547,
#   94.30223492723493,
#   90.92385654885655,
#   94.64007276507277,
#   95.23128898128898,
#   94.64007276507277,
#   84.04365904365905,
#   95.48466735966736,
#   95.31574844074844,
#   93.91891891891892,
#   95.48466735966736,
#   94.97791060291061,
#   94.84797297297297,
#   70.88097713097713,
#   88.3445945945946,
#   95.31574844074844],
#  'valid_f1': [tensor(0.7477, device='cuda:0'),
#   tensor(0.7490, device='cuda:0'),
#   tensor(0.7300, device='cuda:0'),
#   tensor(0.7481, device='cuda:0'),
#   tensor(0.6505, device='cuda:0'),
#   tensor(0.6570, device='cuda:0'),
#   tensor(0.7431, device='cuda:0'),
#   tensor(0.7311, device='cuda:0'),
#   tensor(0.7092, device='cuda:0'),
#   tensor(0.7490, device='cuda:0'),
#   tensor(0.7459, device='cuda:0'),
#   tensor(0.7501, device='cuda:0'),
#   tensor(0.7484, device='cuda:0'),
#   tensor(0.7419, device='cuda:0'),
#   tensor(0.7105, device='cuda:0'),
#   tensor(0.7333, device='cuda:0'),
#   tensor(0.7418, device='cuda:0'),
#   tensor(0.7291, device='cuda:0'),
#   tensor(0.7422, device='cuda:0'),
#   tensor(0.7347, device='cuda:0'),
#   tensor(0.7441, device='cuda:0'),
#   tensor(0.6857, device='cuda:0'),
#   tensor(0.7418, device='cuda:0'),
#   tensor(0.7475, device='cuda:0'),
#   tensor(0.7286, device='cuda:0'),
#   tensor(0.7362, device='cuda:0'),
#   tensor(0.7351, device='cuda:0'),
#   tensor(0.7478, device='cuda:0'),
#   tensor(0.7414, device='cuda:0'),
#   tensor(0.7452, device='cuda:0'),
#   tensor(0.7364, device='cuda:0'),
#   tensor(0.7391, device='cuda:0'),
#   tensor(0.6793, device='cuda:0'),
#   tensor(0.7526, device='cuda:0'),
#   tensor(0.7099, device='cuda:0'),
#   tensor(0.7332, device='cuda:0'),
#   tensor(0.7109, device='cuda:0'),
#   tensor(0.7365, device='cuda:0'),
#   tensor(0.7409, device='cuda:0'),
#   tensor(0.7359, device='cuda:0'),
#   tensor(0.6660, device='cuda:0'),
#   tensor(0.7450, device='cuda:0'),
#   tensor(0.7458, device='cuda:0'),
#   tensor(0.7539, device='cuda:0'),
#   tensor(0.7454, device='cuda:0'),
#   tensor(0.7423, device='cuda:0'),
#   tensor(0.7526, device='cuda:0'),
#   tensor(0.5702, device='cuda:0'),
#   tensor(0.7519, device='cuda:0'),
#   tensor(0.7480, device='cuda:0')]}

# %% [markdown]
# #### Graphs

# %%
plot_loss_curves(model_20_results)

# %%
plot_loss_curves(model_21_results)

# %%
plot_loss_curves(model_22_results)

# %% [markdown]
# ## Incresing the number of epochs - **weighed**

# %% [markdown]
# ### Setting up models

# %%
#Linear
torch.manual_seed(42)

#3 linear layers
#5 nodes
model_23 = XRAYS_linear2(input_shape=409600, # one for every pixel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_23.to(device)
# Out:
# XRAYS_linear2(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
optimizer_23 = torch.optim.SGD(params=model_23.parameters(), lr=0.0001)

# %%
#Non-linear
torch.manual_seed(42)

# 2 linear layers
# 10 nodes
model_24 = XRAYS_nonlinear(input_shape=409600, # one for every pixel
    hidden_units=20, # how many units in the hidden layer
    output_shape=1
)
model_24.to(device)
# Out:
# XRAYS_nonlinear(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=20, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=20, out_features=1, bias=True)
#     (4): ReLU()
#   )
# )

# %%
optimizer_24 = torch.optim.SGD(params=model_24.parameters(), lr=0.0001)

# %%
#CNN
torch.manual_seed(42)

# 1 linear layer
# 5 hidden units
model_25 = XRAYS_CNN(input_shape=1, # 1 colour channel
    hidden_units=5, # how many units in the hidden layer
    output_shape=1
)
model_25.to(device)
# Out:
# XRAYS_CNN(
#   (block_1): Sequential(
#     (0): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=128000, out_features=1, bias=True)
#   )
# )

# %%
optimizer_25 = torch.optim.SGD(params=model_25.parameters(), lr=0.01)

# %% [markdown]
# ### Training

# %%
#Set number of epochs
NUM_EPOCHS = 50

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

#Using weighed loss function
# Train model
model_23_results = train(model=model_23,
                        train_dataloader=train_dataloader,
                        valid_dataloader=valid_dataloader,
                        optimizer=optimizer_23,
                        loss_fn=loss_fn_weighed,
                        epochs=NUM_EPOCHS)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.34145 | Train accuracy: 67.90% | Train F1: 0.74
# Validation loss: 0.30210 | Validation accuracy: 86.12%
#  | Validation F1: 0.90
# Epoch: 1
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.29096 | Train accuracy: 84.32% | Train F1: 0.89
# Validation loss: 0.26173 | Validation accuracy: 90.16%
#  | Validation F1: 0.93
# Epoch: 2
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.25845 | Train accuracy: 86.07% | Train F1: 0.90
# Validation loss: 0.23660 | Validation accuracy: 85.36%
#  | Validation F1: 0.89
# Epoch: 3
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.23580 | Train accuracy: 86.10% | Train F1: 0.90
# Validation loss: 0.21621 | Validation accuracy: 88.05%
#  | Validation F1: 0.91
# Epoch: 4
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.22032 | Train accuracy: 86.81% | Train F1: 0.91
# Validation loss: 0.21129 | Validation accuracy: 81.89%
#  | Validation F1: 0.86
# Epoch: 5
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.20814 | Train accuracy: 87.11% | Train F1: 0.91
# Validation loss: 0.19308 | Validation accuracy: 86.66%
#  | Validation F1: 0.90
# Epoch: 6
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.19648 | Train accuracy: 87.77% | Train F1: 0.91
# Validation loss: 0.18247 | Validation accuracy: 88.31%
#  | Validation F1: 0.92
# Epoch: 7
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.18945 | Train accuracy: 87.77% | Train F1: 0.91
# Validation loss: 0.17912 | Validation accuracy: 85.82%
#  | Validation F1: 0.90
# Epoch: 8
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.18316 | Train accuracy: 87.91% | Train F1: 0.91
# Validation loss: 0.17552 | Validation accuracy: 85.31%
#  | Validation F1: 0.89
# Epoch: 9
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.17672 | Train accuracy: 88.27% | Train F1: 0.92
# Validation loss: 0.16164 | Validation accuracy: 91.01%
#  | Validation F1: 0.94
# Epoch: 10
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.17035 | Train accuracy: 88.84% | Train F1: 0.92
# Validation loss: 0.15779 | Validation accuracy: 92.19%
#  | Validation F1: 0.95
# Epoch: 11
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.16660 | Train accuracy: 88.94% | Train F1: 0.92
# Validation loss: 0.15417 | Validation accuracy: 89.99%
#  | Validation F1: 0.93
# Epoch: 12
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.16301 | Train accuracy: 88.77% | Train F1: 0.92
# Validation loss: 0.14884 | Validation accuracy: 92.19%
#  | Validation F1: 0.95
# Epoch: 13
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.08155 | Train accuracy: 97.13% | Train F1: 0.98
# Validation loss: 0.50526 | Validation accuracy: 88.34%
#  | Validation F1: 0.75
# Epoch: 49
# ---------
# Looked at 0/4077 samples
# Looked at 1024/4077 samples
# Looked at 2048/4077 samples
# Looked at 3072/4077 samples
# Train loss: 0.08202 | Train accuracy: 96.97% | Train F1: 0.98
# Validation loss: 0.13000 | Validation accuracy: 95.32%
#  | Validation F1: 0.75

# %% [markdown]
# ### Results

# %%
model_23_results
# Out:
# {'train_loss': [0.3414453259902075,
#   0.2909565673908219,
#   0.25844730716198683,
#   0.2358043355634436,
#   0.22032395645510405,
#   0.20813529449515045,
#   0.19647895521484315,
#   0.18945199472364038,
#   0.18315589014673606,
#   0.1767220739275217,
#   0.1703523614560254,
#   0.16659608867485076,
#   0.16300870815757662,
#   0.15965064824558794,
#   0.15623675257666036,
#   0.153221984335687,
#   0.149944000528194,
#   0.14822857797844335,
#   0.14568412554217502,
#   0.1433531427755952,
#   0.14117550736409612,
#   0.1401641360425856,
#   0.13809360936284065,
#   0.13690317858709022,
#   0.13514135335572064,
#   0.1333191705052741,
#   0.13247901410795748,
#   0.13079541799379513,
#   0.12969206389971077,
#   0.12854545650770888,
#   0.1277960298175458,
#   0.1263125347031746,
#   0.1261100182600785,
#   0.12421065961825661,
#   0.12370737249148078,
#   0.12400363013148308,
#   0.1212099856347777,
#   0.12164577367366292,
#   0.12124748222413473,
#   0.11963621500763111,
#   0.1196623891883064,
#   0.11895022055250593,
#   0.11736881488468498,
#   0.116465320403222,
#   0.11657735917833634,
#   0.1162625627766829,
#   0.11595945799490437,
#   0.1158074822742492,
#   0.11486630156286992,
#   0.11478582708514296],
#  'train_acc': [67.8955078125,
#   84.31678185096153,
#   86.07459435096153,
#   86.09900841346153,
#   86.80701622596153,
#   87.1112530048077,
#   87.7685546875,
#   87.7704326923077,
#   87.90564903846153,
#   88.26998197115384,
#   88.8427734375,
#   88.9423076923077,
#   88.7714092548077,
#   89.1132061298077,
#   89.41744290865384,
#   89.46814903846153,
#   89.5038311298077,
#   89.58834134615384,
#   89.697265625,
#   89.97896634615384,
#   90.14986478365384,
#   90.34517728365384,
#   90.27193509615384,
#   90.44471153846153,
#   90.73580228365384,
#   90.6494140625,
#   90.72265625,
#   90.9423828125,
#   90.9912109375,
#   90.9912109375,
#   90.9686748798077,
#   91.10201322115384,
#   90.57992788461539,
#   91.15084134615384,
#   91.19966947115384,
#   91.08323317307692,
#   91.6015625,
#   91.11328125,
#   91.5057842548077,
#   91.5283203125,
#   91.6278545673077,
#   91.4081280048077,
#   91.6015625,
#   91.6748046875,
#   91.76119290865384,
#   91.5301983173077,
#   91.68795072115384,
#   91.5301983173077,
#   91.59217247596153,
#   91.6766826923077],
#  'train_f1': [0.7435147259606008,
#   0.88671875,
#   0.8997875354107648,
#   0.9004405286343613,
#   0.9057002111189304,
#   0.907488986784141,
#   0.911904343238966,
#   0.9125702247191011,
#   0.9139351446099911,
#   0.9159501666959116,
#   0.9200349956255468,
#   0.9213286713286714,
#   0.9200629700892077,
#   93.54209979209979,
#   92.86642411642411,
#   93.37318087318087,
#   91.51507276507277,
#   90.16372141372142,
#   93.9643970893971,
#   93.03534303534303],
#  'valid_f1': [0.9002493765586035,
#   0.9325513196480938,
#   0.8940438871473354,
#   0.9142156862745097,
#   0.862565445026178,
#   0.9034267912772586,
#   0.9158993247391037,
#   0.8958990536277602,
#   0.8915662650602408,
#   0.9369369369369369,
#   0.9464390818128311,
#   0.9287020109689214,
#   0.945994065281899,
#   0.9478054567022539,
#   0.8998109640831758,
#   0.9458655562165378,
#   0.9437799043062202,
#   0.9233599019006745,
#   0.9451073985680191,
#   0.9345454545454545,
#   0.9273060476481368,
#   0.9223181257706535,
#   0.9422382671480145,
#   0.9468021518230724,
#   0.9351121892055793,
#   0.9163050216986981,
#   0.926470588235294,
#   0.9454109178164366,
#   0.9323583180987202,
#   0.9508584961515689,
#   0.925812385039853,
#   0.9210850801479655,
#   0.9435096153846154,
#   0.952662721893491,
#   0.9500594530321048,
#   0.927038626609442,
#   0.9050911376492771,
#   0.9402534701267351,
#   0.9388989715668482,
#   0.9434416365824309,
#   0.9388989715668482,
#   0.9544648137196925,
#   0.9557522123893805,
#   0.9558043606364172,
#   0.9506833036244802,
#   0.9544648137196925,
#   0.9401812688821753,
#   0.9297495418448382,
#   0.9592074592074591,
#   0.9518716577540107]}

# %%
model_24_results

# %%
model_25_results

# %% [markdown]
# ### Graphs

# %%
plot_loss_curves(model_23_results)

# %%
plot_loss_curves(model_24_results)

# %%
plot_loss_curves(model_25_results)

# %% [markdown]
# ***
# ## Saving best models
# ***

# %%
# 1. Create models directory
MODEL_PATH = Path("models")
MODEL_PATH.mkdir(parents=True, exist_ok=True)

# %%
# 2. Create model save path
MODEL_NAME = "model_20.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# 3. Save the model state dict
print(f"Saving model to: {MODEL_SAVE_PATH}")
torch.save(obj=model_20.state_dict(), # only saving the state_dict() only saves the models learned parameters
           f=MODEL_SAVE_PATH)
# Out:
# Saving model to: models/model_20.pth

# %%
# 2. Create model save path
MODEL_NAME = "model_21.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# 3. Save the model state dict
print(f"Saving model to: {MODEL_SAVE_PATH}")
torch.save(obj=model_21.state_dict(), # only saving the state_dict() only saves the models learned parameters
           f=MODEL_SAVE_PATH)
# Out:
# Saving model to: models/model_21.pth

# %%
# 2. Create model save path
MODEL_NAME = "model_22.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# 3. Save the model state dict
print(f"Saving model to: {MODEL_SAVE_PATH}")
torch.save(obj=model_22.state_dict(), # only saving the state_dict() only saves the models learned parameters
           f=MODEL_SAVE_PATH)
# Out:
# Saving model to: models/model_22.pth

# %%
# 2. Create model save path
MODEL_NAME = "model_23.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# 3. Save the model state dict
print(f"Saving model to: {MODEL_SAVE_PATH}")
torch.save(obj=model_23.state_dict(), # only saving the state_dict() only saves the models learned parameters
           f=MODEL_SAVE_PATH)
# Out:
# Saving model to: models/model_23.pth

# %%
# 2. Create model save path
MODEL_NAME = "model_24.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# 3. Save the model state dict
print(f"Saving model to: {MODEL_SAVE_PATH}")
torch.save(obj=model_24.state_dict(), # only saving the state_dict() only saves the models learned parameters
           f=MODEL_SAVE_PATH)

# %% [markdown]
# ***
# ## Evaluation
# ***

# %%
#Evaluation function
def test(data_loader: torch.utils.data.DataLoader,
              model: torch.nn.Module,
              accuracy_fn,
              device: torch.device = device):
    y_true = []
    y_pred = []
    test_acc, test_f1 = 0, 0
    model.to(device)
    model.eval() # put model in eval mode
    # Turn on inference context manager
    with torch.inference_mode():
        for entry in data_loader:
            # Send data to GPU
            X = entry['image'].to(device)
            y = entry['labels'].to(device)
            y_true.append(y)

            # 1. Forward pass
            test_logits = model(X).squeeze().to(device)
            test_pred = torch.round(torch.sigmoid(test_logits)).to(device)
            y_pred.append(test_pred)

            # 2. Calculate accuracy
            test_acc += accuracy_fn(y_true=y, y_pred=test_pred)

        # Adjust metrics and return
        y_true = torch.cat(y_true).to('cpu')
        y_true = torch.Tensor.numpy(y_true)
        y_pred = torch.cat(y_pred).to('cpu')
        y_pred = torch.Tensor.numpy(y_pred)
        test_acc /= len(data_loader)
        test_f1 += f1_score(y_true=y_true, y_pred=y_pred)

        results = {
            "test_acc": test_acc,
            "test_f1": test_f1
        }

        return results, y_true, y_pred

# %% [markdown]
# #### Model 20 - Linear

# %%
loaded_model_20 = XRAYS_linear2(input_shape=409600,
    hidden_units=5,
    output_shape=1)

loaded_model_20.to(device)

# Load model state dict
loaded_model_20.load_state_dict(torch.load('models/model_20.pth'))

#Put model to target device (if your data is on GPU, model will have to be on GPU to make predictions)
loaded_model_20.to(device)

print(f"Loaded model:\n{loaded_model_20}")
print(f"Model on device:\n{next(loaded_model_20.parameters()).device}")
# Out:
# Loaded model:
# XRAYS_linear2(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): Linear(in_features=5, out_features=1, bias=True)
#   )
# )
# Model on device:
# cuda:0

# %%
# Set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

#Testing
test_results_model_20, y_test, y_test_pred_model_20 = test(data_loader=test_dataloader,
                                                            model=loaded_model_20,
                                                            accuracy_fn=accuracy_fn,
                                                            device=device)

# %%
test_results_model_20
# Out:
# {'test_acc': 92.21491228070175, 'test_f1': 0.948626045400239}

# %%
cm = confusion_matrix(y_test, y_test_pred_model_20)
ConfusionMatrixDisplay(cm).plot()

# %% [markdown]
# #### Model 21 - Non-linear

# %%
loaded_model_21 = XRAYS_nonlinear(input_shape=409600,
    hidden_units=20,
    output_shape=1)

# Load model state dict
loaded_model_21.load_state_dict(torch.load('models/model_21.pth'))

#Put model to target device (if your data is on GPU, model will have to be on GPU to make predictions)
loaded_model_21.to(device)

print(f"Loaded model:\n{loaded_model_21}")
print(f"Model on device:\n{next(loaded_model_21.parameters()).device}")
# Out:
# Loaded model:
# XRAYS_nonlinear(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=20, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=20, out_features=1, bias=True)
#     (4): ReLU()
#   )
# )
# Model on device:
# cuda:0

# %%
test_results_model_21, y_test, y_test_pred_model_21 = test(data_loader=test_dataloader,
                                                            model=loaded_model_21,
                                                            accuracy_fn=accuracy_fn,
                                                            device=device)

# %%
test_results_model_21
# Out:
# {'test_acc': 93.09210526315789, 'test_f1': 0.9507042253521126}

# %%
cm = confusion_matrix(y_test, y_test_pred_model_21)
ConfusionMatrixDisplay(cm).plot()

# %% [markdown]
# #### Model 22 - CNN

# %%
loaded_model_22 = XRAYS_CNN(input_shape=1,
    hidden_units=5,
    output_shape=1
)

loaded_model_22.to(device)
# Load model state dict
loaded_model_22.load_state_dict(torch.load('models/model_22.pth'))

#Put model to target device (if your data is on GPU, model will have to be on GPU to make predictions)
loaded_model_22.to(device)

print(f"Loaded model:\n{loaded_model_22}")
print(f"Model on device:\n{next(loaded_model_22.parameters()).device}")
# Out:
# Loaded model:
# XRAYS_CNN(
#   (block_1): Sequential(
#     (0): Conv2d(1, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(5, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=128000, out_features=1, bias=True)
#   )
# )
# Model on device:
# cuda:0

# %%
test_results_model_22, y_test, y_test_pred_model_22 = test(data_loader=test_dataloader,
                                                            model=loaded_model_22,
                                                            accuracy_fn=accuracy_fn,
                                                            device=device)

# %%
test_results_model_22
# Out:
# {'test_acc': 93.09210526315789, 'test_f1': 0.9497607655502392}

# %%
cm = confusion_matrix(y_test, y_test_pred_model_22)
ConfusionMatrixDisplay(cm).plot()

# %% [markdown]
# #### Model 23 - Linear weighed

# %%
loaded_model_23 = XRAYS_linear2(input_shape=409600,
    hidden_units=5,
    output_shape=1)

loaded_model_23.to(device)

# Load model state dict
loaded_model_23.load_state_dict(torch.load('models/model_23.pth'))

#Put model to target device (if your data is on GPU, model will have to be on GPU to make predictions)
loaded_model_23.to(device)

print(f"Loaded model:\n{loaded_model_23}")
print(f"Model on device:\n{next(loaded_model_23.parameters()).device}")
# Out:
# Loaded model:
# XRAYS_linear2(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=409600, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): Linear(in_features=5, out_features=1, bias=True)
#   )
# )
# Model on device:
# cuda:0

# %%
test_results_model_23, y_test, y_test_pred_model_23 = test(data_loader=test_dataloader,
                                                            model=loaded_model_23,
                                                            accuracy_fn=accuracy_fn,
                                                            device=device)

# %%
test_results_model_23
# Out:
# {'test_acc': 90.5701754385965, 'test_f1': 0.9336670838548186}

# %%
cm = confusion_matrix(y_test, y_test_pred_model_23)
ConfusionMatrixDisplay(cm).plot()

# %% [markdown]
# Model 24 - Non-linear weighed

# %%
loaded_model_24 = XRAYS_nonlinear(input_shape=409600,
    hidden_units=20,
    output
